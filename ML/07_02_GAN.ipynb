# %% [markdown]
# # GAN

# %% [markdown]
# ## 1-1 GAN이란?

# %% [markdown]
# ### 1-1 Vanilla GAN

# %%
import torch
print(torch.__version__)
# Out:
# 2.0.1+cu118

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR

import numpy as np
from tqdm.auto import tqdm # 진행상태 확인하는 함수

import matplotlib.pyplot as plt

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 88.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.31.0

# %%
#transformers
from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    # transforms.Normalize((0.5, ), (0.5, )) # -1, 1
])

train_dataset = datasets.FashionMNIST('./data', train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST('./data', train=False, transform=transform)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:00<00:00, 115739153.61it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 5164144.94it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 61538900.87it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 26789425.55it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
plt.imshow(train_dataset[0][0].permute(1, 2, 0))

# %%
train_dataset[0][0].shape
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# 학습이 된 Gan모델에 노이즈값을 넣은 뒤 예측한 이미지를 보여주는 함수입니다.

# %%
def plot_generated_images(generator):
    # 100개의 노이즈 값을 생성합니다.
    noise = torch.rand((100, 100), device=device)
    with torch.no_grad():
        make_images = generator(noise).detach().cpu() # 노이즈값을 통해서 GAN으로 이미지 생성합니다.
    make_images = make_images.reshape(100, 1, 28,28) # Mnist 사이즈와 동일하게 바꿔줍니다.
    plt.figure(figsize=(10,10)) # 이미지 크기 지정
    for i in range(make_images.shape[0]): #이미지 갯수 100만큼 반복
        plt.subplot(10, 10, i+1) #바둑판식으로 표현
        plt.imshow(make_images[i].permute(1, 2, 0),plt.get_cmap('gray'))
        plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# Vanilla GAN 모델링에 관한 코드입니다.
# GAN은 2개의 모델이 필수적으로 사용을 하게 됩니다.
#
# 실제이미지와 가짜 이미지를 판별해주는 Discriminator
# 가짜이미지를 생성하는 Generator 모델입니다.
# 모델마다 각자의 optimizer를 갖고 있으며 --> 충돌을 방지를 합니다.
#
# 데이터는 Fashion Mnist데이터를 이용하여 실습하겠습니다.

# %%
epochs = 20  # 반복 횟수를 정해줍니다.
batch_size = 64 # 배치사이즈를 정해줍니다.

# %% [markdown]
# Generator 모델을 만듭니다.
# 입력데이터는 100개의 노이즈 이며 3층으로 쌓은 FFN 입니다.
# 활성함수는 ReLU를 사용하였고, 마지막에는 Tanh를 사용하였습니다.
#
# Binary_crossetropy를 사용하여 이진 분류를 사용하였고, optimizer는 아까 규제를 넣은 adam을 사용하였습니다.
#
# Dropout을 사용하게 되었습니다.
#
# Generator의 최종 결과는 784이고 이는 mnist의 이미지 크기와 동일합니다.

# %%
# 생성자
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.generator = nn.Sequential(
            nn.Linear(100, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(512, 784),
            nn.Tanh(),  # sigmoid의 일종 -1 ~ 1
        )

    def forward(self, x):
        x_prime = self.generator(x)
        return x_prime

# %% [markdown]
# discriminator 모델을 만듭니다.
# 입력데이터는 minist파일의 크기이며 3층으로 쌓은 FFN 모델입니다.
# Generator와 다르게 unit의 수가 점점 줄어드는 것을 확인 할 수 있습니다.
#
# 마지막 활성함수는 sigmoid를 사용함으로서 0 1사이에 거짓 이미지인지 실제 이미지인지를 판별을 해주는 것입니다.

# %%
# 판별자
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.discriminator = nn.Sequential(
            nn.Linear(784, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            # nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

        # for param in self.discriminator.parameters():
        #     param.requires_grad = False

    def forward(self, x):
        output = self.discriminator(x)
        return output

# %% [markdown]
# 이제는 두 모델을 합칩니다.
# 실제이미지와 가짜이미지를 판결하기 위해서 Binary_CrossEntropy를 사용하였고,
# input의 데이터는 가짜이미지이고, output은 실제인지 가짜인지 판별해주는 discriminator의 결과값입니다.

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model_g = Generator()
model_g.to(device)
model_d = Discriminator()
model_d.to(device)

criterion = nn.BCELoss()

#옵티마이저, 손실함수 지정
optimizer_g = optim.Adam(model_g.parameters(), lr=1e-4)
optimizer_d = optim.Adam(model_d.parameters(), lr=1e-4)

scheduler_g = StepLR(optimizer_g, step_size=5, gamma=0.7)
scheduler_d = StepLR(optimizer_d, step_size=5, gamma=0.7)

# %% [markdown]
# 모델을 학습시키는 코드입니다.
#
# 위에서 설정한 Epochs 수만큼 학습을 하게 되고, batch_count만큼 반복하게 됩니다.
#
# 진짜 이미지와 가짜 이미지를 합친 후
# 그 크기만큼의 배열을 생성한 뒤 실제 이미지에는 0.9의 값을 주고 가짜 이미지에는 0의 값을 줍니다.
# 그 후 discriminator를 학습을 시킵니다.
# 배치사이즈 크기만큼 배열을 생성한 뒤 값을 1로 세팅하여 gan에 노이즈값과 함께 학습을 시킵니다.

# %%
# generator가 생성한 이미지를 저장해놓을 리스트입니다.
img_list = []

# 학습에 사용되는 참/거짓의 라벨을 정합니다
real_label = 0.9 # label smoothing = 0.9
fake_label = 0.1

fixed_noise = torch.rand((20, 100), device=device)

total_step = len(train_loader)
for epoch in range(1, epochs + 1):
    for i, (data, _) in enumerate(tqdm(iter(train_loader))):
        # Real 데이터로 discriminator를 학습
        data = data.view(-1, 28*28).to(device)
        # print(data.shape)
        now_batch_size = data.size()[0]

        # 실제 이미지이므로 Discriminator는 1로 판단해야 합니다.
        real_labels = torch.full((now_batch_size, 1), real_label,
                           dtype=torch.float, device=device)
        fake_labels = torch.full((now_batch_size, 1), fake_label,
                           dtype=torch.float, device=device)

        output = model_d(data)  # 원본 데이터
        real_score = output
        d_loss_real = criterion(output, real_labels)    # 원본은 1로 예측해야 한다.

        # Fake 데이터로 discriminator 학습
        noise = torch.randn(now_batch_size, 100).to(device) # 노이즈 데이터를 생성합니다.
        # Generator를 이용해 가짜 이미지를 생성합니다
        # 여기서 generator가 생성한 이미지는 generator에는 영향을 미치지 않기 위해 detach() 합니다.
        fake_data = model_g(noise).detach()
        # print(fake_data.shape)

        # D를 이용해 데이터의 진위를 판별합니다
        output = model_d(fake_data)
        fake_score = output
        # D의 손실값을 계산합니다
        d_loss_fake = criterion(output, fake_labels)    # Fake라고 예측해야 cost가 낮아지도록 학

        optimizer_g.zero_grad()
        optimizer_d.zero_grad()
        loss_discriminator = d_loss_real + d_loss_fake
        loss_discriminator.backward()
        optimizer_d.step()

        # Generator를 학습시킵니다.

        noise = torch.randn(now_batch_size, 100).to(device) # 노이즈 데이터를 생성합니다.
        fake_data = model_g(noise)
        output = model_d(fake_data)

        optimizer_g.zero_grad()
        optimizer_d.zero_grad()
        loss_generator = criterion(output, real_labels) # Fake 데이터인데 real로 예측하면 cost 커짐
        loss_generator.backward()
        # G를 업데이트 합니다
        optimizer_g.step()

        if (i+1) % 200 == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, epochs, i+1, total_step, loss_discriminator.item(), loss_generator.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    scheduler_g.step()
    scheduler_d.step()

    with torch.no_grad():
        fake = model_g(fixed_noise).detach().cpu()

    make_images = fake.reshape(20, 1, 28, 28) # Mnist 사이즈와 동일하게 바꿔줍니다.
    img_list.append(make_images)
# Out:
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch [1/20], Step [200/938], d_loss: 0.7662, g_loss: 2.0122, D(x): 0.81, D(G(z)): 0.22
# Epoch [1/20], Step [400/938], d_loss: 0.8399, g_loss: 2.2362, D(x): 0.71, D(G(z)): 0.18
# Epoch [1/20], Step [600/938], d_loss: 0.7342, g_loss: 2.5365, D(x): 0.79, D(G(z)): 0.14
# Epoch [1/20], Step [800/938], d_loss: 0.7172, g_loss: 2.4855, D(x): 0.83, D(G(z)): 0.15
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch [2/20], Step [200/938], d_loss: 0.8991, g_loss: 1.2339, D(x): 0.81, D(G(z)): 0.34
# Epoch [2/20], Step [400/938], d_loss: 0.9137, g_loss: 1.3132, D(x): 0.84, D(G(z)): 0.35
# Epoch [2/20], Step [600/938], d_loss: 0.7662, g_loss: 1.9477, D(x): 0.83, D(G(z)): 0.17
# Epoch [2/20], Step [800/938], d_loss: 0.7685, g_loss: 1.9034, D(x): 0.84, D(G(z)): 0.18
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch [3/20], Step [200/938], d_loss: 0.7609, g_loss: 1.8633, D(x): 0.87, D(G(z)): 0.17
# Epoch [3/20], Step [400/938], d_loss: 0.7515, g_loss: 1.9119, D(x): 0.80, D(G(z)): 0.15
# Epoch [3/20], Step [600/938], d_loss: 0.7447, g_loss: 1.9545, D(x): 0.83, D(G(z)): 0.14
# Epoch [3/20], Step [800/938], d_loss: 0.7294, g_loss: 2.0844, D(x): 0.82, D(G(z)): 0.13
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch [4/20], Step [200/938], d_loss: 0.7304, g_loss: 2.2238, D(x): 0.87, D(G(z)): 0.13
# Epoch [4/20], Step [400/938], d_loss: 0.6976, g_loss: 1.8217, D(x): 0.88, D(G(z)): 0.15
# Epoch [4/20], Step [600/938], d_loss: 0.7520, g_loss: 1.9666, D(x): 0.84, D(G(z)): 0.17
# Epoch [4/20], Step [800/938], d_loss: 0.7393, g_loss: 2.0378, D(x): 0.85, D(G(z)): 0.18
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch [5/20], Step [200/938], d_loss: 0.7771, g_loss: 1.8581, D(x): 0.83, D(G(z)): 0.20
# Epoch [5/20], Step [400/938], d_loss: 0.8884, g_loss: 1.7932, D(x): 0.81, D(G(z)): 0.25
# Epoch [5/20], Step [600/938], d_loss: 0.7345, g_loss: 2.2093, D(x): 0.83, D(G(z)): 0.13
# Epoch [5/20], Step [800/938], d_loss: 0.7454, g_loss: 1.8982, D(x): 0.85, D(G(z)): 0.19
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch [6/20], Step [200/938], d_loss: 0.7957, g_loss: 1.7677, D(x): 0.85, D(G(z)): 0.22
# Epoch [6/20], Step [400/938], d_loss: 0.8166, g_loss: 1.6823, D(x): 0.76, D(G(z)): 0.18
# Epoch [6/20], Step [600/938], d_loss: 0.7769, g_loss: 2.0547, D(x): 0.82, D(G(z)): 0.17
# Epoch [6/20], Step [800/938], d_loss: 0.7999, g_loss: 2.0217, D(x): 0.87, D(G(z)): 0.20
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch [20/20], Step [200/938], d_loss: 0.8724, g_loss: 1.6772, D(x): 0.76, D(G(z)): 0.22
# Epoch [20/20], Step [400/938], d_loss: 0.8425, g_loss: 1.4563, D(x): 0.82, D(G(z)): 0.26
# Epoch [20/20], Step [600/938], d_loss: 0.9089, g_loss: 1.3896, D(x): 0.85, D(G(z)): 0.33
# Epoch [20/20], Step [800/938], d_loss: 0.9352, g_loss: 1.3791, D(x): 0.74, D(G(z)): 0.27

# %%
model_g
# Out:
# Generator(
#   (generator): Sequential(
#     (0): Linear(in_features=100, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=784, bias=True)
#     (5): Tanh()
#   )
# )

# %%
img_list[0]
# Out:
# tensor([[[[ 1.4122e-01, -1.0795e-01,  5.1611e-02,  ...,  8.7681e-02,
#            -3.4851e-02,  3.3592e-02],
#           [-2.5231e-05, -1.1295e-01, -4.0142e-02,  ..., -2.8127e-01,
#            -9.6926e-02,  1.4483e-01],
#           [-2.3924e-01, -1.4967e-01, -3.5477e-02,  ...,  1.1604e-01,
#            -1.0205e-01, -8.3842e-02],
#           ...,
#           [ 2.1218e-01,  3.0830e-02,  6.2212e-02,  ...,  2.2887e-01,
#             1.7797e-01, -7.4939e-02],
#           [-1.5083e-01,  7.6127e-03, -1.4249e-01,  ..., -2.3511e-02,
#             1.5950e-01,  2.3730e-01],
#           [ 1.1204e-01,  1.2140e-01,  1.2744e-01,  ...,  1.1022e-01,
#            -1.8364e-02,  5.0872e-02]]],
#
#
#         [[[ 1.3328e-01, -1.0106e-01,  1.9374e-02,  ...,  7.4334e-02,
#            -2.7092e-02,  2.7829e-02],
#           [-3.8381e-03, -9.1307e-02, -3.3231e-02,  ..., -2.4627e-01,
#            -8.7884e-02,  1.0146e-01],
#           [-2.0602e-01, -1.3189e-01, -2.1850e-02,  ...,  9.3624e-02,
#            -9.0417e-02, -6.6205e-02],
#           ...,
#           [ 1.6997e-01,  2.4505e-02,  5.5805e-02,  ...,  1.9346e-01,
#             1.5609e-01, -4.9991e-02],
#           [-1.0823e-01, -1.3308e-02, -1.3320e-01,  ..., -3.8142e-02,
#             1.3043e-01,  2.1377e-01],
#           [ 7.4195e-02,  8.3549e-02,  1.1402e-01,  ...,  6.8773e-02,
#            -1.9358e-02,  4.2395e-02]]],
#
#
#         [[[ 1.2230e-01, -9.0380e-02,  2.0791e-02,  ...,  7.5604e-02,
#            -1.9043e-02,  3.3815e-02],
#           [-1.6562e-02, -1.0766e-01, -4.2570e-02,  ..., -2.4843e-01,
#            -9.6061e-02,  1.0155e-01],
#           [-2.0713e-01, -1.3833e-01, -2.9802e-02,  ...,  1.1005e-01,
#            -8.6852e-02, -7.2279e-02],
#           ...,
#           [ 1.6745e-01,  2.5201e-02,  5.3784e-02,  ...,  1.9926e-01,
#             1.4826e-01, -5.5388e-02],
#           [-1.1509e-01, -6.4296e-04, -1.2200e-01,  ..., -2.2221e-02,
#             1.4652e-01,  2.1789e-01],
#           [ 8.8018e-02,  9.5059e-02,  1.2175e-01,  ...,  7.7199e-02,
#            -1.6764e-02,  3.7290e-02]]],
#
#
#         ...,
#
#
#         [[[ 1.3439e-01, -9.8254e-02,  3.0383e-02,  ...,  9.4564e-02,
#            -2.5133e-03,  4.1638e-02],
#           [-1.8175e-02, -1.2010e-01, -5.0899e-02,  ..., -2.8166e-01,
#            -1.1567e-01,  1.2480e-01],
#           [-2.4743e-01, -1.4882e-01, -5.0644e-02,  ...,  1.3303e-01,
#            -1.1662e-01, -8.4206e-02],
#           ...,
#           [ 2.0517e-01,  8.6149e-03,  8.3990e-02,  ...,  2.2874e-01,
#             1.8371e-01, -5.4717e-02],
#           [-1.2758e-01,  7.6011e-03, -1.5675e-01,  ..., -5.1181e-02,
#             1.5664e-01,  2.6677e-01],
#           [ 8.2204e-02,  1.0865e-01,  1.5532e-01,  ...,  1.1390e-01,
#            -2.4176e-02,  4.9434e-02]]],
#
#
#         [[[ 1.2429e-01, -1.0391e-01,  2.6873e-02,  ...,  7.8902e-02,
#            -3.7230e-02,  2.6240e-02],
#           [-1.6938e-02, -1.1983e-01, -2.5707e-02,  ..., -2.9134e-01,
#            -1.2008e-01,  1.2375e-01],
#           [-2.2442e-01, -1.6120e-01, -3.6251e-02,  ...,  1.2033e-01,
#            -9.9130e-02, -6.3641e-02],
#           ...,
#           [ 1.8363e-01,  1.1413e-02,  8.7719e-02,  ...,  2.4256e-01,
#             1.8171e-01, -4.7941e-02],
#           [-1.3396e-01, -2.3107e-02, -1.6723e-01,  ..., -1.9905e-02,
#             1.6385e-01,  2.4131e-01],
#           [ 1.2226e-01,  1.0201e-01,  1.3239e-01,  ...,  1.0629e-01,
#            -2.2323e-02,  3.2617e-02]]],
#
#
#         [[[ 1.2881e-01, -1.0238e-01,  4.7650e-02,  ...,  8.3635e-02,
#            -3.1626e-02,  1.8462e-02],
#           [-3.6544e-04, -1.2698e-01, -5.1722e-02,  ..., -2.7169e-01,
#            -1.1113e-01,  1.4938e-01],
#           [-2.3271e-01, -1.4874e-01, -4.6075e-02,  ...,  1.2933e-01,
#            -1.1364e-01, -8.7430e-02],
#           ...,
#           [ 1.8749e-01,  4.6427e-02,  5.8827e-02,  ...,  2.3408e-01,
#             1.8023e-01, -4.6305e-02],
#           [-1.1531e-01,  9.8498e-04, -1.5519e-01,  ..., -2.7897e-02,
#             1.3200e-01,  2.3406e-01],
#           [ 1.2530e-01,  1.0323e-01,  1.4252e-01,  ...,  9.5434e-02,
#            -2.3560e-02,  4.1508e-02]]]])

# %%
make_images.shape[0]
# Out:
# 20

# %%
i
# Out:
# 937

# %%
make_images.shape
# Out:
# torch.Size([20, 1, 28, 28])

# %%
len(img_list)
# Out:
# 20

# %%
for make_images in img_list:
    if make_images.shape[1] != 784:
        plt.figure(figsize=(4,4)) # 이미지 크기 지정
        for i in range(make_images.shape[0]): #이미지 갯수만큼 반복
            plt.subplot(4, 5, i+1) #바둑판식으로 표현
            plt.imshow(make_images[i].permute(1, 2, 0))
            plt.axis('off')
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plot_generated_images(model_g)

# %% [markdown]
# ### 1-2 DCGAN

# %% [markdown]
# 이번에는 GAN의 응용모델인 DCGAN을 설명하겠습니다.
# DCGAN은 "Deep Convolutional Generative Adversarial Nets"의 약자이며 FFN 부분을 CNN으로 바꾼 부분입니다.
# DCGAN이 탄생하게 된 것은 기존에 있던 GAN이 불안정하며 새로 만들어진 결과물들이 좋은지를 판단하기가 어렵게 되어 나오게 된 것입니다.
# 기존에 있던 CNN과 다른 점은 Pooling layer를 사용하지 않고 이를 strides로 교체를 한 것입니다.

# %% [markdown]
# Vanilla GAN을 했을 당시에는 -1 ~ 1 사이의 값으로 하였으나
# DCGAN에서는 결과가 좋지 않아 0 ~ 1 사이의 값으로 정규화를 진행하였습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html

# %%
import os

os.path.abspath('.')
# Out:
# '/content'

# %%
import zipfile

house_zip = zipfile.ZipFile('/content/drive/MyDrive/ML/data/img_align_celeba.zip')
house_zip.extractall('./data/celeba')
house_zip.close()

# %%
dataroot = "./data/celeba/img_align_celeba/"

# %%
image_list = []

for fn in os.listdir(dataroot):
    image_list.append(dataroot+fn)

# %%
set([img.split('.')[-1] for img in image_list])
# Out:
# {'jpg'}

# %%
image_list[0]
# Out:
# './data/celeba/img_align_celeba/090090.jpg'

# %%
import cv2
img = cv2.imread(image_list[0])

import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
face_dataset = datasets.ImageFolder(root='./data/celeba',
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.CenterCrop(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

# %%
transform = transforms.Compose([
                            transforms.Resize(64),
                            transforms.CenterCrop(64),
                            transforms.ToTensor(),
                            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# %%
from torch.utils.data import Dataset

# %%
class CustomerDataset(Dataset):
    def __init__(self, img_path_list, transform=None):
        self.img_path_list = img_path_list
        self.transform = transform

    def __getitem__(self, index):
        img_path = self.img_path_list[index]
        image = cv2.imread(img_path)

        if self.transform is not None:
            image = self.transform(image=image)['image']

        label = '_'.join(img_path.split('_')[2:])[:-5]
        return image, label

    def __len__(self):
        return len(self.img_path_list)

# %%
from PIL import Image

# %%
class FaceDataset(Dataset):
    def __init__(self, image_file_list:list, labels=None, transform=None):
        self.image_list = image_file_list   # 데이터 저장하는 부분
        self.transform = transform
        self.labels = labels

    def __getitem__(self, index):
        # [1, 2, 3][1] -> 2
        # index로 특정 이미지 경로 가져옴
        image_file_path = self.image_list[index]
        # print(image_file_path)

        # 해당 경로로 이미지 불러옴
        image = Image.open(image_file_path)
        # image = cv2.imread(image_file_path)

        # transform 있으면, transform 적용
        if self.transform:
            # print('트랜스폼 적용')
            image = self.transform(image)

        # 그렇게 처리된 이미지 변환
        return image

    def __len__(self):
        # 개수 세기
        # print('개수 반환')
        return len(self.image_list)

face_dataset = FaceDataset(image_list, transform=transform)

# %%
image_list
# Out:
# ['./data/celeba/img_align_celeba/090090.jpg',
#  './data/celeba/img_align_celeba/048518.jpg',
#  './data/celeba/img_align_celeba/106964.jpg',
#  './data/celeba/img_align_celeba/054744.jpg',
#  './data/celeba/img_align_celeba/178083.jpg',
#  './data/celeba/img_align_celeba/161707.jpg',
#  './data/celeba/img_align_celeba/113726.jpg',
#  './data/celeba/img_align_celeba/104775.jpg',
#  './data/celeba/img_align_celeba/079497.jpg',
#  './data/celeba/img_align_celeba/149560.jpg',
#  './data/celeba/img_align_celeba/191338.jpg',
#  './data/celeba/img_align_celeba/163730.jpg',
#  './data/celeba/img_align_celeba/199200.jpg',
#  './data/celeba/img_align_celeba/019788.jpg',
#  './data/celeba/img_align_celeba/171175.jpg',
#  './data/celeba/img_align_celeba/022427.jpg',
#  './data/celeba/img_align_celeba/046202.jpg',
#  './data/celeba/img_align_celeba/135554.jpg',
#  './data/celeba/img_align_celeba/117430.jpg',
#  './data/celeba/img_align_celeba/085617.jpg',
#  './data/celeba/img_align_celeba/003360.jpg',
#  './data/celeba/img_align_celeba/021745.jpg',
#  './data/celeba/img_align_celeba/054757.jpg',
#  './data/celeba/img_align_celeba/007473.jpg',
#  './data/celeba/img_align_celeba/126202.jpg',
#  './data/celeba/img_align_celeba/186490.jpg',
#  './data/celeba/img_align_celeba/076354.jpg',
#  './data/celeba/img_align_celeba/165067.jpg',
#  './data/celeba/img_align_celeba/087485.jpg',
#  './data/celeba/img_align_celeba/037896.jpg',
#  './data/celeba/img_align_celeba/172292.jpg',
#  './data/celeba/img_align_celeba/069423.jpg',
#  './data/celeba/img_align_celeba/068170.jpg',
#  './data/celeba/img_align_celeba/070899.jpg',
#  './data/celeba/img_align_celeba/028801.jpg',
#  './data/celeba/img_align_celeba/094459.jpg',
#  './data/celeba/img_align_celeba/180023.jpg',
#  './data/celeba/img_align_celeba/130851.jpg',
#  './data/celeba/img_align_celeba/049319.jpg',
#  './data/celeba/img_align_celeba/189420.jpg',
#  './data/celeba/img_align_celeba/067454.jpg',
#  './data/celeba/img_align_celeba/065750.jpg',
#  './data/celeba/img_align_celeba/120975.jpg',
#  './data/celeba/img_align_celeba/127821.jpg',
#  './data/celeba/img_align_celeba/108304.jpg',
#  './data/celeba/img_align_celeba/011985.jpg',
#  './data/celeba/img_align_celeba/024960.jpg',
#  './data/celeba/img_align_celeba/018754.jpg',
#  './data/celeba/img_align_celeba/105936.jpg',
#  './data/celeba/img_align_celeba/123515.jpg',
#  './data/celeba/img_align_celeba/038695.jpg',
#  './data/celeba/img_align_celeba/074233.jpg',
#  './data/celeba/img_align_celeba/173150.jpg',
#  './data/celeba/img_align_celeba/085706.jpg',
#  './data/celeba/img_align_celeba/072073.jpg',
#  './data/celeba/img_align_celeba/090035.jpg',
#  './data/celeba/img_align_celeba/035316.jpg',
#  './data/celeba/img_align_celeba/019403.jpg',
#  './data/celeba/img_align_celeba/192644.jpg',
#  './data/celeba/img_align_celeba/201637.jpg',
#  './data/celeba/img_align_celeba/072122.jpg',
#  './data/celeba/img_align_celeba/159178.jpg',
#  './data/celeba/img_align_celeba/033985.jpg',
#  './data/celeba/img_align_celeba/140366.jpg',
#  './data/celeba/img_align_celeba/171840.jpg',
#  './data/celeba/img_align_celeba/053360.jpg',
#  './data/celeba/img_align_celeba/190450.jpg',
#  './data/celeba/img_align_celeba/057575.jpg',
#  './data/celeba/img_align_celeba/049423.jpg',
#  './data/celeba/img_align_celeba/102352.jpg',
#  './data/celeba/img_align_celeba/112587.jpg',
#  './data/celeba/img_align_celeba/004242.jpg',
#  './data/celeba/img_align_celeba/112002.jpg',
#  './data/celeba/img_align_celeba/176479.jpg',
#  './data/celeba/img_align_celeba/057180.jpg',
#  './data/celeba/img_align_celeba/131824.jpg',
#  './data/celeba/img_align_celeba/059262.jpg',
#  './data/celeba/img_align_celeba/070364.jpg',
#  './data/celeba/img_align_celeba/027281.jpg',
#  './data/celeba/img_align_celeba/049845.jpg',
#  './data/celeba/img_align_celeba/093052.jpg',
#  './data/celeba/img_align_celeba/178213.jpg',
#  './data/celeba/img_align_celeba/154063.jpg',
#  './data/celeba/img_align_celeba/070662.jpg',
#  './data/celeba/img_align_celeba/163549.jpg',
#  './data/celeba/img_align_celeba/074847.jpg',
#  './data/celeba/img_align_celeba/092755.jpg',
#  './data/celeba/img_align_celeba/020522.jpg',
#  './data/celeba/img_align_celeba/106532.jpg',
#  './data/celeba/img_align_celeba/112764.jpg',
#  './data/celeba/img_align_celeba/089923.jpg',
#  './data/celeba/img_align_celeba/099968.jpg',
#  './data/celeba/img_align_celeba/101590.jpg',
#  './data/celeba/img_align_celeba/152412.jpg',
#  './data/celeba/img_align_celeba/170597.jpg',
#  './data/celeba/img_align_celeba/065310.jpg',
#  './data/celeba/img_align_celeba/047748.jpg',
#  './data/celeba/img_align_celeba/052517.jpg',
#  './data/celeba/img_align_celeba/118889.jpg',
#  './data/celeba/img_align_celeba/066945.jpg',
#  './data/celeba/img_align_celeba/026416.jpg',
#  './data/celeba/img_align_celeba/196329.jpg',
#  './data/celeba/img_align_celeba/143158.jpg',
#  './data/celeba/img_align_celeba/100883.jpg',
#  './data/celeba/img_align_celeba/016574.jpg',
#  './data/celeba/img_align_celeba/104278.jpg',
#  './data/celeba/img_align_celeba/182409.jpg',
#  './data/celeba/img_align_celeba/024622.jpg',
#  './data/celeba/img_align_celeba/158548.jpg',
#  './data/celeba/img_align_celeba/015680.jpg',
#  './data/celeba/img_align_celeba/171615.jpg',
#  './data/celeba/img_align_celeba/015232.jpg',
#  './data/celeba/img_align_celeba/041841.jpg',
#  './data/celeba/img_align_celeba/163874.jpg',
#  './data/celeba/img_align_celeba/174143.jpg',
#  './data/celeba/img_align_celeba/045164.jpg',
#  './data/celeba/img_align_celeba/074968.jpg',
#  './data/celeba/img_align_celeba/133021.jpg',
#  './data/celeba/img_align_celeba/073674.jpg',
#  './data/celeba/img_align_celeba/113531.jpg',
#  './data/celeba/img_align_celeba/041900.jpg',
#  './data/celeba/img_align_celeba/162714.jpg',
#  './data/celeba/img_align_celeba/197913.jpg',
#  './data/celeba/img_align_celeba/134617.jpg',
#  './data/celeba/img_align_celeba/064704.jpg',
#  './data/celeba/img_align_celeba/034512.jpg',
#  './data/celeba/img_align_celeba/063095.jpg',
#  './data/celeba/img_align_celeba/200357.jpg',
#  './data/celeba/img_align_celeba/066685.jpg',
#  './data/celeba/img_align_celeba/168278.jpg',
#  './data/celeba/img_align_celeba/083761.jpg',
#  './data/celeba/img_align_celeba/118458.jpg',
#  './data/celeba/img_align_celeba/008280.jpg',
#  './data/celeba/img_align_celeba/161826.jpg',
#  './data/celeba/img_align_celeba/073751.jpg',
#  './data/celeba/img_align_celeba/104374.jpg',
#  './data/celeba/img_align_celeba/067014.jpg',
#  './data/celeba/img_align_celeba/162304.jpg',
#  './data/celeba/img_align_celeba/148963.jpg',
#  './data/celeba/img_align_celeba/197611.jpg',
#  './data/celeba/img_align_celeba/035430.jpg',
#  './data/celeba/img_align_celeba/115289.jpg',
#  './data/celeba/img_align_celeba/062557.jpg',
#  './data/celeba/img_align_celeba/055795.jpg',
#  './data/celeba/img_align_celeba/022448.jpg',
#  './data/celeba/img_align_celeba/195117.jpg',
#  './data/celeba/img_align_celeba/003417.jpg',
#  './data/celeba/img_align_celeba/184504.jpg',
#  './data/celeba/img_align_celeba/019606.jpg',
#  './data/celeba/img_align_celeba/060666.jpg',
#  './data/celeba/img_align_celeba/113290.jpg',
#  './data/celeba/img_align_celeba/088925.jpg',
#  './data/celeba/img_align_celeba/126181.jpg',
#  './data/celeba/img_align_celeba/153287.jpg',
#  './data/celeba/img_align_celeba/201907.jpg',
#  './data/celeba/img_align_celeba/117547.jpg',
#  './data/celeba/img_align_celeba/087905.jpg',
#  './data/celeba/img_align_celeba/091753.jpg',
#  './data/celeba/img_align_celeba/148541.jpg',
#  './data/celeba/img_align_celeba/061297.jpg',
#  './data/celeba/img_align_celeba/062547.jpg',
#  './data/celeba/img_align_celeba/186656.jpg',
#  './data/celeba/img_align_celeba/156592.jpg',
#  './data/celeba/img_align_celeba/094627.jpg',
#  './data/celeba/img_align_celeba/137421.jpg',
#  './data/celeba/img_align_celeba/184720.jpg',
#  './data/celeba/img_align_celeba/198952.jpg',
#  './data/celeba/img_align_celeba/017191.jpg',
#  './data/celeba/img_align_celeba/042597.jpg',
#  './data/celeba/img_align_celeba/014551.jpg',
#  './data/celeba/img_align_celeba/072502.jpg',
#  './data/celeba/img_align_celeba/066268.jpg',
#  './data/celeba/img_align_celeba/055553.jpg',
#  './data/celeba/img_align_celeba/002101.jpg',
#  './data/celeba/img_align_celeba/014460.jpg',
#  './data/celeba/img_align_celeba/143188.jpg',
#  './data/celeba/img_align_celeba/161604.jpg',
#  './data/celeba/img_align_celeba/064669.jpg',
#  './data/celeba/img_align_celeba/134106.jpg',
#  './data/celeba/img_align_celeba/200959.jpg',
#  './data/celeba/img_align_celeba/192685.jpg',
#  './data/celeba/img_align_celeba/166353.jpg',
#  './data/celeba/img_align_celeba/148697.jpg',
#  './data/celeba/img_align_celeba/098845.jpg',
#  './data/celeba/img_align_celeba/174790.jpg',
#  './data/celeba/img_align_celeba/089157.jpg',
#  './data/celeba/img_align_celeba/202397.jpg',
#  './data/celeba/img_align_celeba/064241.jpg',
#  './data/celeba/img_align_celeba/045694.jpg',
#  './data/celeba/img_align_celeba/155276.jpg',
#  './data/celeba/img_align_celeba/103991.jpg',
#  './data/celeba/img_align_celeba/092461.jpg',
#  './data/celeba/img_align_celeba/193459.jpg',
#  './data/celeba/img_align_celeba/176096.jpg',
#  './data/celeba/img_align_celeba/037954.jpg',
#  './data/celeba/img_align_celeba/090236.jpg',
#  './data/celeba/img_align_celeba/176580.jpg',
#  './data/celeba/img_align_celeba/164219.jpg',
#  './data/celeba/img_align_celeba/061134.jpg',
#  './data/celeba/img_align_celeba/156292.jpg',
#  './data/celeba/img_align_celeba/047054.jpg',
#  './data/celeba/img_align_celeba/156373.jpg',
#  './data/celeba/img_align_celeba/139206.jpg',
#  './data/celeba/img_align_celeba/178103.jpg',
#  './data/celeba/img_align_celeba/095213.jpg',
#  './data/celeba/img_align_celeba/157882.jpg',
#  './data/celeba/img_align_celeba/019468.jpg',
#  './data/celeba/img_align_celeba/043404.jpg',
#  './data/celeba/img_align_celeba/058319.jpg',
#  './data/celeba/img_align_celeba/129566.jpg',
#  './data/celeba/img_align_celeba/156065.jpg',
#  './data/celeba/img_align_celeba/084014.jpg',
#  './data/celeba/img_align_celeba/095031.jpg',
#  './data/celeba/img_align_celeba/125077.jpg',
#  './data/celeba/img_align_celeba/082305.jpg',
#  './data/celeba/img_align_celeba/072424.jpg',
#  './data/celeba/img_align_celeba/163988.jpg',
#  './data/celeba/img_align_celeba/172420.jpg',
#  './data/celeba/img_align_celeba/017667.jpg',
#  './data/celeba/img_align_celeba/181196.jpg',
#  './data/celeba/img_align_celeba/176381.jpg',
#  './data/celeba/img_align_celeba/111816.jpg',
#  './data/celeba/img_align_celeba/178211.jpg',
#  './data/celeba/img_align_celeba/063103.jpg',
#  './data/celeba/img_align_celeba/115076.jpg',
#  './data/celeba/img_align_celeba/004359.jpg',
#  './data/celeba/img_align_celeba/119605.jpg',
#  './data/celeba/img_align_celeba/193087.jpg',
#  './data/celeba/img_align_celeba/036834.jpg',
#  './data/celeba/img_align_celeba/124616.jpg',
#  './data/celeba/img_align_celeba/187732.jpg',
#  './data/celeba/img_align_celeba/092167.jpg',
#  './data/celeba/img_align_celeba/202534.jpg',
#  './data/celeba/img_align_celeba/140760.jpg',
#  './data/celeba/img_align_celeba/017176.jpg',
#  './data/celeba/img_align_celeba/121673.jpg',
#  './data/celeba/img_align_celeba/089594.jpg',
#  './data/celeba/img_align_celeba/033219.jpg',
#  './data/celeba/img_align_celeba/026806.jpg',
#  './data/celeba/img_align_celeba/038122.jpg',
#  './data/celeba/img_align_celeba/198210.jpg',
#  './data/celeba/img_align_celeba/042798.jpg',
#  './data/celeba/img_align_celeba/065323.jpg',
#  './data/celeba/img_align_celeba/007140.jpg',
#  './data/celeba/img_align_celeba/041326.jpg',
#  './data/celeba/img_align_celeba/018430.jpg',
#  './data/celeba/img_align_celeba/112519.jpg',
#  './data/celeba/img_align_celeba/066812.jpg',
#  './data/celeba/img_align_celeba/064642.jpg',
#  './data/celeba/img_align_celeba/144276.jpg',
#  './data/celeba/img_align_celeba/186497.jpg',
#  './data/celeba/img_align_celeba/167639.jpg',
#  './data/celeba/img_align_celeba/029671.jpg',
#  './data/celeba/img_align_celeba/199242.jpg',
#  './data/celeba/img_align_celeba/023570.jpg',
#  './data/celeba/img_align_celeba/128945.jpg',
#  './data/celeba/img_align_celeba/072784.jpg',
#  './data/celeba/img_align_celeba/089134.jpg',
#  './data/celeba/img_align_celeba/072189.jpg',
#  './data/celeba/img_align_celeba/027557.jpg',
#  './data/celeba/img_align_celeba/189030.jpg',
#  './data/celeba/img_align_celeba/031804.jpg',
#  './data/celeba/img_align_celeba/059845.jpg',
#  './data/celeba/img_align_celeba/117478.jpg',
#  './data/celeba/img_align_celeba/029658.jpg',
#  './data/celeba/img_align_celeba/054624.jpg',
#  './data/celeba/img_align_celeba/134344.jpg',
#  './data/celeba/img_align_celeba/121370.jpg',
#  './data/celeba/img_align_celeba/139890.jpg',
#  './data/celeba/img_align_celeba/163473.jpg',
#  './data/celeba/img_align_celeba/033092.jpg',
#  './data/celeba/img_align_celeba/170108.jpg',
#  './data/celeba/img_align_celeba/120101.jpg',
#  './data/celeba/img_align_celeba/182877.jpg',
#  './data/celeba/img_align_celeba/068567.jpg',
#  './data/celeba/img_align_celeba/129611.jpg',
#  './data/celeba/img_align_celeba/200776.jpg',
#  './data/celeba/img_align_celeba/168745.jpg',
#  './data/celeba/img_align_celeba/019248.jpg',
#  './data/celeba/img_align_celeba/011037.jpg',
#  './data/celeba/img_align_celeba/085461.jpg',
#  './data/celeba/img_align_celeba/033695.jpg',
#  './data/celeba/img_align_celeba/104248.jpg',
#  './data/celeba/img_align_celeba/149666.jpg',
#  './data/celeba/img_align_celeba/032753.jpg',
#  './data/celeba/img_align_celeba/109800.jpg',
#  './data/celeba/img_align_celeba/117243.jpg',
#  './data/celeba/img_align_celeba/117534.jpg',
#  './data/celeba/img_align_celeba/192773.jpg',
#  './data/celeba/img_align_celeba/137968.jpg',
#  './data/celeba/img_align_celeba/041567.jpg',
#  './data/celeba/img_align_celeba/157814.jpg',
#  './data/celeba/img_align_celeba/039174.jpg',
#  './data/celeba/img_align_celeba/072474.jpg',
#  './data/celeba/img_align_celeba/005258.jpg',
#  './data/celeba/img_align_celeba/190573.jpg',
#  './data/celeba/img_align_celeba/109622.jpg',
#  './data/celeba/img_align_celeba/060219.jpg',
#  './data/celeba/img_align_celeba/062322.jpg',
#  './data/celeba/img_align_celeba/002647.jpg',
#  './data/celeba/img_align_celeba/011208.jpg',
#  './data/celeba/img_align_celeba/165340.jpg',
#  './data/celeba/img_align_celeba/101346.jpg',
#  './data/celeba/img_align_celeba/084109.jpg',
#  './data/celeba/img_align_celeba/128700.jpg',
#  './data/celeba/img_align_celeba/006010.jpg',
#  './data/celeba/img_align_celeba/174735.jpg',
#  './data/celeba/img_align_celeba/104382.jpg',
#  './data/celeba/img_align_celeba/020512.jpg',
#  './data/celeba/img_align_celeba/037369.jpg',
#  './data/celeba/img_align_celeba/074423.jpg',
#  './data/celeba/img_align_celeba/202574.jpg',
#  './data/celeba/img_align_celeba/141357.jpg',
#  './data/celeba/img_align_celeba/028479.jpg',
#  './data/celeba/img_align_celeba/093486.jpg',
#  './data/celeba/img_align_celeba/123979.jpg',
#  './data/celeba/img_align_celeba/041600.jpg',
#  './data/celeba/img_align_celeba/121758.jpg',
#  './data/celeba/img_align_celeba/096121.jpg',
#  './data/celeba/img_align_celeba/168357.jpg',
#  './data/celeba/img_align_celeba/101582.jpg',
#  './data/celeba/img_align_celeba/032835.jpg',
#  './data/celeba/img_align_celeba/023074.jpg',
#  './data/celeba/img_align_celeba/127317.jpg',
#  './data/celeba/img_align_celeba/100296.jpg',
#  './data/celeba/img_align_celeba/174187.jpg',
#  './data/celeba/img_align_celeba/142261.jpg',
#  './data/celeba/img_align_celeba/136900.jpg',
#  './data/celeba/img_align_celeba/198419.jpg',
#  './data/celeba/img_align_celeba/181316.jpg',
#  './data/celeba/img_align_celeba/064972.jpg',
#  './data/celeba/img_align_celeba/065946.jpg',
#  './data/celeba/img_align_celeba/098317.jpg',
#  './data/celeba/img_align_celeba/140464.jpg',
#  './data/celeba/img_align_celeba/094268.jpg',
#  './data/celeba/img_align_celeba/107591.jpg',
#  './data/celeba/img_align_celeba/023080.jpg',
#  './data/celeba/img_align_celeba/097922.jpg',
#  './data/celeba/img_align_celeba/083992.jpg',
#  './data/celeba/img_align_celeba/022433.jpg',
#  './data/celeba/img_align_celeba/096474.jpg',
#  './data/celeba/img_align_celeba/089565.jpg',
#  './data/celeba/img_align_celeba/134261.jpg',
#  './data/celeba/img_align_celeba/177474.jpg',
#  './data/celeba/img_align_celeba/196941.jpg',
#  './data/celeba/img_align_celeba/131207.jpg',
#  './data/celeba/img_align_celeba/164012.jpg',
#  './data/celeba/img_align_celeba/195619.jpg',
#  './data/celeba/img_align_celeba/139184.jpg',
#  './data/celeba/img_align_celeba/046124.jpg',
#  './data/celeba/img_align_celeba/193869.jpg',
#  './data/celeba/img_align_celeba/143458.jpg',
#  './data/celeba/img_align_celeba/024101.jpg',
#  './data/celeba/img_align_celeba/145649.jpg',
#  './data/celeba/img_align_celeba/000588.jpg',
#  './data/celeba/img_align_celeba/117191.jpg',
#  './data/celeba/img_align_celeba/052586.jpg',
#  './data/celeba/img_align_celeba/053471.jpg',
#  './data/celeba/img_align_celeba/196541.jpg',
#  './data/celeba/img_align_celeba/120241.jpg',
#  './data/celeba/img_align_celeba/110134.jpg',
#  './data/celeba/img_align_celeba/111520.jpg',
#  './data/celeba/img_align_celeba/039350.jpg',
#  './data/celeba/img_align_celeba/068013.jpg',
#  './data/celeba/img_align_celeba/100617.jpg',
#  './data/celeba/img_align_celeba/022929.jpg',
#  './data/celeba/img_align_celeba/174773.jpg',
#  './data/celeba/img_align_celeba/075989.jpg',
#  './data/celeba/img_align_celeba/031648.jpg',
#  './data/celeba/img_align_celeba/151839.jpg',
#  './data/celeba/img_align_celeba/049461.jpg',
#  './data/celeba/img_align_celeba/182063.jpg',
#  './data/celeba/img_align_celeba/162999.jpg',
#  './data/celeba/img_align_celeba/064421.jpg',
#  './data/celeba/img_align_celeba/139948.jpg',
#  './data/celeba/img_align_celeba/198424.jpg',
#  './data/celeba/img_align_celeba/201492.jpg',
#  './data/celeba/img_align_celeba/007418.jpg',
#  './data/celeba/img_align_celeba/049303.jpg',
#  ...]

# %%
face_dataset[0].shape
# Out:
# torch.Size([3, 64, 64])

# %%
len(face_dataset)
# Out:
# 202599

# %%
batch_size=128
dataloader = torch.utils.data.DataLoader(face_dataset, batch_size=batch_size,
                                         shuffle=True, num_workers=0)

# %% [markdown]
# Generator를 선언하는 부분입니다.
# 해당 코드에서 중요한 것은 Strides 부분입니다.
# 처음 보는 함수들이 있습니다.
#
# LeakyReLU는 활성함수 중 하나입니다.
# Relu는 0이하인 값들은 전부 0으로 바꿔주지만 LeakyReLU는 0으로 수렴하게 해줍니다.
# Conv2DTranspose라는 Deconvolution라고 불리우고 이미지 해상도를 올리 때 사용합니다.
# Conv2D와 사용법은 동일하고 Conv2D를 거꾸로 해놓은 버전이라고 생각하시면 됩니다.
#
# 처음 FFN으로 통하여 이미지의 크기를 지정해줍니다.
# 그 후 리사이즈를 통해 이미지가 Conv2D에 학습 할 수 있도록 바꿔줍니다.
#
# Conv2DTranspose에서 필터사이즈 256, 커널사이즈 4, strides 2, padding은 same으로 설정 하였습니다.
# 다층 Conv2D를 지나고 Dense로 가게 되면 28  28  1 이미지의 형태가 됩니다.
#
# Summary 부분에서 자세하게 설명하겠습니다.

# %%
# 생성자
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.generator = nn.Sequential(
            nn.ConvTranspose2d(64, 64*8, kernel_size=4, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(64*8),
            nn.ReLU(),

            nn.ConvTranspose2d(64*8, 64*4, kernel_size=4, stride=2, padding=1), # 같은 크기로 Conv2D
            nn.BatchNorm2d(64*4),
            nn.ReLU(),

            nn.ConvTranspose2d(64*4, 64*2, kernel_size=4, stride=2, padding=1), # Deconvolution
            nn.BatchNorm2d(64*2),
            nn.ReLU(),

            nn.ConvTranspose2d(64*2, 64*1, kernel_size=4, stride=2, padding=1), # 같은 크기로 Conv2D
            nn.BatchNorm2d(64*1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1), # 같은 크기로 Conv2D
            nn.Tanh(),
        )

    def forward(self, x):
        x = self.generator(x)
        return x

# %%
import torchsummary
torchsummary.summary(Generator().cuda(), (64, 1, 1, ))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 512, 4, 4]         524,288
#        BatchNorm2d-2            [-1, 512, 4, 4]           1,024
#               ReLU-3            [-1, 512, 4, 4]               0
#    ConvTranspose2d-4            [-1, 256, 8, 8]       2,097,408
#        BatchNorm2d-5            [-1, 256, 8, 8]             512
#               ReLU-6            [-1, 256, 8, 8]               0
#    ConvTranspose2d-7          [-1, 128, 16, 16]         524,416
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#               ReLU-9          [-1, 128, 16, 16]               0
#   ConvTranspose2d-10           [-1, 64, 32, 32]         131,136
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#              ReLU-12           [-1, 64, 32, 32]               0
#   ConvTranspose2d-13            [-1, 3, 64, 64]           3,075
#              Tanh-14            [-1, 3, 64, 64]               0
# ================================================================
# Total params: 3,282,243
# Trainable params: 3,282,243
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.00
# Params size (MB): 12.52
# Estimated Total Size (MB): 15.52
# ----------------------------------------------------------------

# %% [markdown]
# Summary를 살펴 보게 되면
# 첫 Conv2D를 지나게 되면 14 * 14 * 256의 이미지 형태가 됩니다.
# Conv2DTranspose 부분에서 지나게 되면서 28 * 28 * 256 형태로 바뀌게 됩니다.
# 이는 strides부분이 기존에 있던 크기를 확장시키게 됩니다.
# strides가 3이면 이미지는 42 * 42 * 256 형태가 되는 것입니다.
# padding을 설정하게 됨으로써 strides 부분만 영향을 주게 되는 것입니다.
#
# 위에 코드에서 strides와 padding을 조정하고 summary를 출력을 해보면 이해하기 쉬울 것입니다.

# %% [markdown]
# Discriminator는 FFN 부분이 Conv2D로 바뀐 말고는 달라진 점은 없습니다.
#
# Conv2D 코드를 보면 strides 부분이 추가가 되어있으며 Polling 부분이 없는 것이 확인 됩니다.
#
# Adam이 아닌 RMSprop으로 진행하였습니다.

# %%
# 생성자
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.discriminator = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(p=0.4),
            nn.Conv2d(64, 64*2, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64*2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(p=0.4),
            nn.Conv2d(64*2, 64*4, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64*4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64*4, 64*8, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64*8),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Flatten(),
            # nn.Dropout(p=0.4),
            nn.Linear(64*8*4*4, 1),
            nn.Sigmoid(),

        )

    def forward(self, x):
        x = self.discriminator(x)
        return x

# %% [markdown]
# Summary를 살펴보면 Padding이 설정되지 않기 대문에 커널 사이즈의 영향을 받아 이미지 크기가 줄어 들었습니다.
# 또한 strides 부분이 2로 설정 되어있있기에 이미지의 2번 째 Conv2D 부터는 이미지 크기가 줄어드는 게 보입니다.

# %%
torchsummary.summary(Discriminator().cuda(), (3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           3,136
#          LeakyReLU-2           [-1, 64, 32, 32]               0
#            Dropout-3           [-1, 64, 32, 32]               0
#             Conv2d-4          [-1, 128, 16, 16]         131,200
#        BatchNorm2d-5          [-1, 128, 16, 16]             256
#          LeakyReLU-6          [-1, 128, 16, 16]               0
#            Dropout-7          [-1, 128, 16, 16]               0
#             Conv2d-8            [-1, 256, 8, 8]         524,544
#        BatchNorm2d-9            [-1, 256, 8, 8]             512
#         LeakyReLU-10            [-1, 256, 8, 8]               0
#            Conv2d-11            [-1, 512, 4, 4]       2,097,664
#       BatchNorm2d-12            [-1, 512, 4, 4]           1,024
#         LeakyReLU-13            [-1, 512, 4, 4]               0
#           Flatten-14                 [-1, 8192]               0
#            Linear-15                    [-1, 1]           8,193
#           Sigmoid-16                    [-1, 1]               0
# ================================================================
# Total params: 2,766,529
# Trainable params: 2,766,529
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 3.13
# Params size (MB): 10.55
# Estimated Total Size (MB): 13.73
# ----------------------------------------------------------------

# %% [markdown]
# 학습을 시키는 부분은 GAN 기본 모델과 다르지 않습니다.

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model_g = Generator()
model_g.to(device)
model_d = Discriminator()
model_d.to(device)

# for para in model_d.parameters():
#     para.requires_grad = False

criterion = nn.BCELoss().cuda()
optimizer_g = optim.Adam(model_g.parameters(), lr=2e-3)
optimizer_d = optim.Adam(model_d.parameters(), lr=2e-3)
scheduler_g = StepLR(optimizer_g, step_size=5, gamma=0.7)
scheduler_d = StepLR(optimizer_d, step_size=5, gamma=0.7)

# %%
# generator가 생성한 이미지를 저장해놓을 리스트입니다.
img_list = []

# 학습에 사용되는 참/거짓의 라벨을 정합니다
real_label = 0.9 # label smoothing = 0.9
fake_label = 0.

fixed_noise = torch.rand((20, 64, 1, 1), device=device)

epochs = 5
total_step = len(dataloader)

for epoch in range(1, epochs + 1):
    for i, data in enumerate(tqdm(iter(dataloader))):
        # Real 데이터로 discriminator를 학습
        data = data.to(device)
        # print(data.shape)
        now_batch_size = data.size()[0]

        # 실제 이미지이므로 Discriminator는 1로 판단해야 합니다.
        real_labels = torch.full((now_batch_size, 1), real_label,
                           dtype=torch.float, device=device)
        fake_labels = torch.full((now_batch_size, 1), fake_label,
                           dtype=torch.float, device=device)

        output = model_d(data)
        real_score = output
        d_loss_real = criterion(output, real_labels)

        # Fake 데이터로 discriminator 학습
        noise = torch.randn(now_batch_size, 64, 1, 1).to(device) # 노이즈 데이터를 생성합니다.
        # Generator를 이용해 가짜 이미지를 생성합니다
        fake_data = model_g(noise).detach()
        # print(fake_data.shape)

        # D를 이용해 데이터의 진위를 판별합니다
        output = model_d(fake_data)
        fake_score = output
        # D의 손실값을 계산합니다
        d_loss_fake = criterion(output, fake_labels)

        optimizer_g.zero_grad()
        optimizer_d.zero_grad()
        loss_discriminator = d_loss_real + d_loss_fake
        loss_discriminator.backward()
        optimizer_d.step()

        # Generator를 학습시킵니다.

        noise = torch.randn(now_batch_size, 64, 1, 1).to(device) # 노이즈 데이터를 생성합니다.
        fake_data = model_g(noise)
        output = model_d(fake_data)

        optimizer_g.zero_grad()
        optimizer_d.zero_grad()
        loss_generator = criterion(output, real_labels)
        loss_generator.backward()
        # G를 업데이트 합니다
        optimizer_g.step()

        if (i+1) % 50 == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, epochs, i+1, total_step, loss_discriminator.item(), loss_generator.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    scheduler_g.step()
    scheduler_d.step()

    with torch.no_grad():
        fake = model_g(fixed_noise).detach().cpu()

    img_list.append(fake)
# Out:
#   0%|          | 0/1583 [00:00<?, ?it/s]
# Epoch [1/5], Step [50/1583], d_loss: 0.4628, g_loss: 6.2507, D(x): 0.85, D(G(z)): 0.05
# Epoch [1/5], Step [100/1583], d_loss: 0.4192, g_loss: 7.3576, D(x): 0.91, D(G(z)): 0.03
# Epoch [1/5], Step [150/1583], d_loss: 0.3994, g_loss: 7.6401, D(x): 0.86, D(G(z)): 0.03
# Epoch [1/5], Step [200/1583], d_loss: 0.3733, g_loss: 5.2795, D(x): 0.87, D(G(z)): 0.02
# Epoch [1/5], Step [250/1583], d_loss: 0.3759, g_loss: 5.8692, D(x): 0.92, D(G(z)): 0.03
# Epoch [1/5], Step [300/1583], d_loss: 0.4014, g_loss: 4.8351, D(x): 0.90, D(G(z)): 0.02
# Epoch [1/5], Step [350/1583], d_loss: 0.3717, g_loss: 5.5465, D(x): 0.85, D(G(z)): 0.01
# Epoch [1/5], Step [400/1583], d_loss: 0.3498, g_loss: 7.5666, D(x): 0.90, D(G(z)): 0.00
# Epoch [1/5], Step [450/1583], d_loss: 0.3478, g_loss: 6.6823, D(x): 0.88, D(G(z)): 0.00
# Epoch [1/5], Step [500/1583], d_loss: 0.3572, g_loss: 4.8127, D(x): 0.93, D(G(z)): 0.00
# Epoch [1/5], Step [550/1583], d_loss: 0.3673, g_loss: 6.8167, D(x): 0.94, D(G(z)): 0.01
# Epoch [1/5], Step [600/1583], d_loss: 0.4204, g_loss: 5.4938, D(x): 0.97, D(G(z)): 0.01
# Epoch [1/5], Step [650/1583], d_loss: 0.3438, g_loss: 5.8156, D(x): 0.92, D(G(z)): 0.00
# Epoch [1/5], Step [700/1583], d_loss: 0.4618, g_loss: 6.2601, D(x): 0.89, D(G(z)): 0.05
# Epoch [1/5], Step [750/1583], d_loss: 0.3551, g_loss: 6.3211, D(x): 0.93, D(G(z)): 0.00
# Epoch [1/5], Step [800/1583], d_loss: 0.3884, g_loss: 7.4987, D(x): 0.82, D(G(z)): 0.00
# Epoch [1/5], Step [850/1583], d_loss: 0.3858, g_loss: 5.4880, D(x): 0.89, D(G(z)): 0.01
# Epoch [1/5], Step [900/1583], d_loss: 0.3690, g_loss: 5.4451, D(x): 0.87, D(G(z)): 0.01
# Epoch [3/5], Step [350/1583], d_loss: 0.4766, g_loss: 3.0452, D(x): 0.79, D(G(z)): 0.08
# Epoch [3/5], Step [400/1583], d_loss: 0.4104, g_loss: 5.4817, D(x): 0.87, D(G(z)): 0.01
# Epoch [3/5], Step [450/1583], d_loss: 1.0215, g_loss: 5.6735, D(x): 0.45, D(G(z)): 0.00
# Epoch [3/5], Step [500/1583], d_loss: 0.5316, g_loss: 3.3507, D(x): 0.80, D(G(z)): 0.10
# Epoch [3/5], Step [550/1583], d_loss: 0.4073, g_loss: 7.8931, D(x): 0.82, D(G(z)): 0.00
# Epoch [3/5], Step [600/1583], d_loss: 0.3759, g_loss: 5.3791, D(x): 0.86, D(G(z)): 0.02
# Epoch [3/5], Step [650/1583], d_loss: 0.4872, g_loss: 3.7559, D(x): 0.95, D(G(z)): 0.08
# Epoch [3/5], Step [700/1583], d_loss: 0.5181, g_loss: 3.4019, D(x): 0.71, D(G(z)): 0.01
# Epoch [3/5], Step [750/1583], d_loss: 0.3786, g_loss: 4.7328, D(x): 0.88, D(G(z)): 0.01
# Epoch [3/5], Step [800/1583], d_loss: 0.6530, g_loss: 5.4616, D(x): 0.62, D(G(z)): 0.01
# Epoch [3/5], Step [850/1583], d_loss: 0.4662, g_loss: 4.0514, D(x): 0.78, D(G(z)): 0.02
# Epoch [3/5], Step [900/1583], d_loss: 0.4600, g_loss: 4.3746, D(x): 0.80, D(G(z)): 0.02
# Epoch [3/5], Step [950/1583], d_loss: 0.6298, g_loss: 5.7500, D(x): 0.65, D(G(z)): 0.01
# Epoch [3/5], Step [1000/1583], d_loss: 0.4580, g_loss: 5.2021, D(x): 0.95, D(G(z)): 0.05
# Epoch [3/5], Step [1050/1583], d_loss: 0.4277, g_loss: 5.0765, D(x): 0.85, D(G(z)): 0.03
# Epoch [3/5], Step [1100/1583], d_loss: 0.4093, g_loss: 2.9801, D(x): 0.84, D(G(z)): 0.02
# Epoch [3/5], Step [1150/1583], d_loss: 0.4692, g_loss: 5.1462, D(x): 0.92, D(G(z)): 0.06
# Epoch [3/5], Step [1200/1583], d_loss: 0.4175, g_loss: 5.0712, D(x): 0.89, D(G(z)): 0.03
# Epoch [3/5], Step [1250/1583], d_loss: 0.6268, g_loss: 3.3070, D(x): 0.96, D(G(z)): 0.16
# Epoch [3/5], Step [1300/1583], d_loss: 0.3906, g_loss: 5.0637, D(x): 0.93, D(G(z)): 0.02
# Epoch [3/5], Step [1350/1583], d_loss: 0.4694, g_loss: 4.5137, D(x): 0.89, D(G(z)): 0.06
# Epoch [3/5], Step [1400/1583], d_loss: 0.3940, g_loss: 4.6209, D(x): 0.89, D(G(z)): 0.02
# Epoch [3/5], Step [1450/1583], d_loss: 0.3816, g_loss: 4.4090, D(x): 0.92, D(G(z)): 0.02
# Epoch [3/5], Step [1500/1583], d_loss: 0.4151, g_loss: 5.1569, D(x): 0.80, D(G(z)): 0.01
# Epoch [3/5], Step [1550/1583], d_loss: 0.4267, g_loss: 4.3173, D(x): 0.85, D(G(z)): 0.04
#   0%|          | 0/1583 [00:00<?, ?it/s]
# Epoch [4/5], Step [50/1583], d_loss: 0.4930, g_loss: 5.2429, D(x): 0.72, D(G(z)): 0.00
# Epoch [4/5], Step [100/1583], d_loss: 0.4523, g_loss: 4.0327, D(x): 0.95, D(G(z)): 0.04
# Epoch [4/5], Step [150/1583], d_loss: 0.5520, g_loss: 5.1235, D(x): 0.95, D(G(z)): 0.04
# Epoch [4/5], Step [200/1583], d_loss: 0.4487, g_loss: 4.5668, D(x): 0.83, D(G(z)): 0.04
# Epoch [4/5], Step [250/1583], d_loss: 0.3897, g_loss: 4.5298, D(x): 0.85, D(G(z)): 0.01
# Epoch [4/5], Step [300/1583], d_loss: 0.4106, g_loss: 4.1516, D(x): 0.94, D(G(z)): 0.03
# Epoch [4/5], Step [350/1583], d_loss: 0.4292, g_loss: 4.7952, D(x): 0.90, D(G(z)): 0.01
# Epoch [4/5], Step [400/1583], d_loss: 0.4893, g_loss: 5.7189, D(x): 0.75, D(G(z)): 0.00
# Epoch [4/5], Step [450/1583], d_loss: 0.4402, g_loss: 3.8933, D(x): 0.89, D(G(z)): 0.03
# Epoch [4/5], Step [500/1583], d_loss: 0.4856, g_loss: 4.0760, D(x): 0.96, D(G(z)): 0.07
# Epoch [4/5], Step [550/1583], d_loss: 0.3601, g_loss: 4.4841, D(x): 0.87, D(G(z)): 0.01
# Epoch [4/5], Step [600/1583], d_loss: 0.4645, g_loss: 5.1075, D(x): 0.75, D(G(z)): 0.01
# Epoch [4/5], Step [650/1583], d_loss: 0.5339, g_loss: 6.0370, D(x): 0.68, D(G(z)): 0.00
# Epoch [4/5], Step [700/1583], d_loss: 0.4184, g_loss: 4.5058, D(x): 0.79, D(G(z)): 0.01
# Epoch [4/5], Step [750/1583], d_loss: 0.4373, g_loss: 3.6884, D(x): 0.94, D(G(z)): 0.05
# Epoch [4/5], Step [800/1583], d_loss: 0.3751, g_loss: 3.9339, D(x): 0.91, D(G(z)): 0.02
# Epoch [4/5], Step [850/1583], d_loss: 0.3590, g_loss: 5.1487, D(x): 0.90, D(G(z)): 0.01
# Epoch [4/5], Step [900/1583], d_loss: 0.3761, g_loss: 4.2187, D(x): 0.94, D(G(z)): 0.01
# Epoch [4/5], Step [950/1583], d_loss: 0.3939, g_loss: 4.5528, D(x): 0.88, D(G(z)): 0.02
# Epoch [4/5], Step [1000/1583], d_loss: 0.4034, g_loss: 5.1869, D(x): 0.92, D(G(z)): 0.02
# Epoch [4/5], Step [1050/1583], d_loss: 0.4088, g_loss: 4.5728, D(x): 0.91, D(G(z)): 0.04
# Epoch [4/5], Step [1100/1583], d_loss: 0.3997, g_loss: 6.0119, D(x): 0.88, D(G(z)): 0.01
# Epoch [4/5], Step [1150/1583], d_loss: 0.4843, g_loss: 4.7702, D(x): 0.87, D(G(z)): 0.03
# Epoch [4/5], Step [1200/1583], d_loss: 0.4228, g_loss: 4.2407, D(x): 0.93, D(G(z)): 0.03
# Epoch [4/5], Step [1250/1583], d_loss: 0.4373, g_loss: 3.7782, D(x): 0.88, D(G(z)): 0.05
# Epoch [4/5], Step [1300/1583], d_loss: 0.4319, g_loss: 6.5779, D(x): 0.79, D(G(z)): 0.00
# Epoch [4/5], Step [1350/1583], d_loss: 0.5306, g_loss: 3.2044, D(x): 0.75, D(G(z)): 0.08
# Epoch [4/5], Step [1400/1583], d_loss: 0.5743, g_loss: 3.8062, D(x): 0.66, D(G(z)): 0.02
# Epoch [4/5], Step [1450/1583], d_loss: 0.5061, g_loss: 4.8857, D(x): 0.73, D(G(z)): 0.02
# Epoch [4/5], Step [1500/1583], d_loss: 0.4754, g_loss: 3.2260, D(x): 0.94, D(G(z)): 0.08
# Epoch [4/5], Step [1550/1583], d_loss: 0.4381, g_loss: 4.8932, D(x): 0.80, D(G(z)): 0.01
#   0%|          | 0/1583 [00:00<?, ?it/s]
# Epoch [5/5], Step [50/1583], d_loss: 0.4136, g_loss: 5.1078, D(x): 0.81, D(G(z)): 0.01
# Epoch [5/5], Step [100/1583], d_loss: 0.4215, g_loss: 4.5747, D(x): 0.86, D(G(z)): 0.02
# Epoch [5/5], Step [150/1583], d_loss: 0.4106, g_loss: 4.6447, D(x): 0.91, D(G(z)): 0.04
# Epoch [5/5], Step [200/1583], d_loss: 0.4212, g_loss: 3.6876, D(x): 0.92, D(G(z)): 0.03
# Epoch [5/5], Step [250/1583], d_loss: 0.4837, g_loss: 3.6597, D(x): 0.90, D(G(z)): 0.07
# Epoch [5/5], Step [300/1583], d_loss: 0.4265, g_loss: 5.7123, D(x): 0.81, D(G(z)): 0.01
# Epoch [5/5], Step [350/1583], d_loss: 0.3729, g_loss: 4.0904, D(x): 0.88, D(G(z)): 0.01
# Epoch [5/5], Step [400/1583], d_loss: 0.5108, g_loss: 4.0679, D(x): 0.72, D(G(z)): 0.01
# Epoch [5/5], Step [450/1583], d_loss: 0.4620, g_loss: 4.8137, D(x): 0.78, D(G(z)): 0.00
# Epoch [5/5], Step [500/1583], d_loss: 0.5030, g_loss: 3.3981, D(x): 0.94, D(G(z)): 0.10
# Epoch [5/5], Step [550/1583], d_loss: 0.5469, g_loss: 4.1058, D(x): 0.97, D(G(z)): 0.08
# Epoch [5/5], Step [600/1583], d_loss: 0.4295, g_loss: 6.3744, D(x): 0.84, D(G(z)): 0.01
# Epoch [5/5], Step [650/1583], d_loss: 0.4536, g_loss: 3.7829, D(x): 0.95, D(G(z)): 0.02
# Epoch [5/5], Step [700/1583], d_loss: 0.4118, g_loss: 6.3782, D(x): 0.92, D(G(z)): 0.01
# Epoch [5/5], Step [750/1583], d_loss: 0.4223, g_loss: 3.2448, D(x): 0.91, D(G(z)): 0.04
# Epoch [5/5], Step [800/1583], d_loss: 0.5222, g_loss: 4.5831, D(x): 0.98, D(G(z)): 0.02
# Epoch [5/5], Step [850/1583], d_loss: 0.5959, g_loss: 3.5986, D(x): 0.99, D(G(z)): 0.05
# Epoch [5/5], Step [900/1583], d_loss: 0.4414, g_loss: 5.0782, D(x): 0.77, D(G(z)): 0.02
# Epoch [5/5], Step [950/1583], d_loss: 0.3962, g_loss: 6.7295, D(x): 0.91, D(G(z)): 0.01
# Epoch [5/5], Step [1000/1583], d_loss: 0.4280, g_loss: 4.9882, D(x): 0.81, D(G(z)): 0.01
# Epoch [5/5], Step [1050/1583], d_loss: 0.3930, g_loss: 4.2230, D(x): 0.87, D(G(z)): 0.02
# Epoch [5/5], Step [1100/1583], d_loss: 0.4863, g_loss: 4.3068, D(x): 0.78, D(G(z)): 0.04
# Epoch [5/5], Step [1150/1583], d_loss: 0.5272, g_loss: 4.7526, D(x): 0.98, D(G(z)): 0.02
# Epoch [5/5], Step [1200/1583], d_loss: 0.3979, g_loss: 5.4605, D(x): 0.86, D(G(z)): 0.01
# Epoch [5/5], Step [1250/1583], d_loss: 0.3971, g_loss: 3.8779, D(x): 0.90, D(G(z)): 0.03
# Epoch [5/5], Step [1300/1583], d_loss: 0.3979, g_loss: 4.1179, D(x): 0.91, D(G(z)): 0.02
# Epoch [5/5], Step [1350/1583], d_loss: 0.4369, g_loss: 3.8436, D(x): 0.80, D(G(z)): 0.02
# Epoch [5/5], Step [1400/1583], d_loss: 0.4156, g_loss: 3.4467, D(x): 0.94, D(G(z)): 0.03
# Epoch [5/5], Step [1450/1583], d_loss: 0.5099, g_loss: 3.0444, D(x): 0.87, D(G(z)): 0.11
# Epoch [5/5], Step [1500/1583], d_loss: 0.9151, g_loss: 5.0952, D(x): 0.51, D(G(z)): 0.01
# Epoch [5/5], Step [1550/1583], d_loss: 0.4557, g_loss: 4.3579, D(x): 0.85, D(G(z)): 0.03

# %%
while True:pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-534b7a74019f> in <cell line: 1>()
# ----> 1 while True:pass
#
# KeyboardInterrupt:

# %%
make_images[i][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-b6fe7688c112> in <cell line: 1>()
# ----> 1 make_images[i][0]
#
# IndexError: index 1582 is out of bounds for dimension 0 with size 20

# %%
denorm = transforms.Compose([
                            transforms.Normalize((-1 * 0.5 / 0.5, -1 * 0.5 / 0.5, -1 * 0.5 / 0.5), (1.0 / 0.5, 1.0 / 0.5, 1.0 / 0.5)),
                           ])

# %%
denorm(make_images[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-b0709cd13669> in <cell line: 1>()
# ----> 1 denorm(make_images[i])
#
# IndexError: index 1582 is out of bounds for dimension 0 with size 20

# %%
for make_images in img_list:
    # if make_images.shape[1] != 784:
    plt.figure(figsize=(4,4)) # 이미지 크기 지정
    for i in range(make_images.shape[0]): #이미지 갯수만큼 반복
        plt.subplot(4, 5, i+1) #바둑판식으로 표현
        plt.imshow(denorm(make_images[i]).permute(1, 2, 0))
        plt.axis('off')
    plt.show()

# %%
import matplotlib.pyplot as plt
def plot_generated_images(generator):
    # 100개의 노이즈 값을 생성합니다.
    noise = torch.rand((100, 64, 1, 1), device=device)
    with torch.no_grad():
        make_images = generator(noise).detach().cpu() # 노이즈값을 통해서 GAN으로 이미지 생성합니다.
    make_images = make_images.reshape(100, 3, 64, 64) # Mnist 사이즈와 동일하게 바꿔줍니다.
    plt.figure(figsize=(10,10)) # 이미지 크기 지정
    for i in range(make_images.shape[0]): #이미지 갯수 100만큼 반복
        plt.subplot(10, 10, i+1) #바둑판식으로 표현
        plt.imshow(denorm(make_images[i]).permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()

# %%
plot_generated_images(model_g)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

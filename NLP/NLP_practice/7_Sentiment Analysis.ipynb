# %% [markdown]
# # 감정분석(Sentiment Analysis)

# %% [markdown]
# # 1 사전기반 감정분석

# %%
#KnuSentiLex 다운로드
# !wget https://raw.githubusercontent.com/park1200656/KnuSentiLex/master/pos_pol_word.txt
# !wget https://raw.githubusercontent.com/park1200656/KnuSentiLex/master/neg_pol_word.txt
# Out:
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
dct = {}

# 긍정단어 조회
with open("pos_pol_word.txt", "r") as f :
    dct['pos'] = f.read().split("\n")[19:]

# 부정단어 조회
with open("neg_pol_word.txt", "r") as f :
    dct['neg'] = f.read().split("\n")[19:]

print(dct['pos'][:10])
print(dct['neg'][:10])
# Out:
# ['(-;', '(^^)', '(^-^)', '(^^*', '(^_^)', '(^o^)', '*^^*', '/^o^\\', ':(', ":'-("]
# ['가난', '가난뱅이', '가난살이', '가난살이하다', '가난설음', '가난에', '가난에 쪼들려서', '가난하게', '가난하고', '가난하고 어렵다']

# %%
txt = "코로나19의 여파로 전 세계 교사들과 학생들 모두 혼란스러운 시기를 보내고 있습니다. 초유의 상황에서도, 학생들을 위해 최선을 다하려는 선생님들의 노력이 계속되고 있는데요. 어려움 속에서, 선생님들은 어떤 방법으로 사랑을 전하고 있을까요? 뉴스G에서 전해드립니다. [리포트] 중국 저장성의 한 산골 마을. 초등학교 교사 왕진량 씨는 지난 2월 말부터, 매일 새벽 다섯 시면 부지런히 집을 나섭니다. 온라인 수업을 받을 수 없는, 깊은 산골 마을에 살고 있는 학생들을 찾아가기 위해서인데요. 선생님이 하루 동안 이동하는 거리는 대략 30km정도. 차도 없이 도보로 네 개의 마을을 돌아다니며 학생들을 만납니다. 매일 이어지는 강행군이지만, 오로지 아이들의 학습이 중단되어서는 안 된다는 생각뿐입니다. 혹시 모를 사태에 대비해 학생들과의 접촉은 최대한 줄입니다. 숙제를 내주고, 검사 후에 모르는 문제를 알려주는 식으로 일대일 수업을 진행하고 있는데요. 아이들에게 배우는 즐거움이 얼마나 소중한 것인지 잘 알기에, 선생님은 이렇게라도 수업을 할 수 있다는 데서 행복을 느낍니다. 영국의 한 초등학교 교사인 젠 포울스 씨는 매일 아침, 무거운 짐을 앞 뒤, 양 옆으로 짊어지고 씩씩하게 발걸음을 옮깁니다. 코로나19로 학교가 문을 닫은 뒤, 형편이 어려운 학생들을 위해 매일 78인분의 점심 도시락을 배달하고 있는데요. 선생님이 재직 중인 초등학교는 전체 학생의 41퍼센트가 무상 급식 대상자이기 때문입니다. 도시락의 무게는 18kg, 걸어야 하는 거리는 8km에 달하지만 기다리는 학생들을 생각하며 지치지 않고 발걸음을 재촉합니다. 학생들은 창문을 통해서 반갑게 인사하기도 하고, 선생님이 볼 수 있게 감사 메시지를 붙여 놓기도 하는데요. 선생님이 정성껏 준비해 손수 배달한 사랑의 도시락. 봉쇄된 도시의 굶주린 아이들에게 소중한 한 끼 식사, 그 이상의 의미가 되고 있습니다. 미국 사우스다코타 주의 중학교 수학 교사인 크리스 와바 씨는, 커다란 화이트보드를 들고 학생의 집을 찾았습니다. 온라인 수업 후, 학생에게 이메일로 방정식 풀이법에 대한 질문을 받았기 때문인데요. 이메일로 답변해주는 것보다 직접 풀이 과정을 보여주는 게 낫다는 생각이었죠. 깜짝 놀란 학생을 마주한 채, 선생님은 현관문 앞에서 열정적으로 문제를 풀기 시작했습니다. 이 열정적인 강의는, 학생이 풀이법을 완벽히 이해할 때까지 이어졌는데요. 바이러스는 전 세계 교실에 혼란을 불러왔지만, 선생님들의 노력은 저마다의 방식으로 계속되고 있습니다. 어려움 속에서도 학생들을 위해 안간힘을 쓰고 있는 모든 선생님들에게, 응원과 박수를 함께 보냅니다."

# %%
# 텍스트에 positive 사전에 있는 토큰이 있는지
# 텍스트에 negatvie 사전에 있는 토큰이 있는지
pos_count = 0
neg_count = 0
for token in txt.split():
    pos_count += token in dct['pos']
    neg_count += token in dct['neg']

# %%
pos_count, neg_count
# Out:
# (12, 6)

# %% [markdown]
# # 2 나이브 베이즈 분류기 활용 감정분석

# %% [markdown]
# ## 2.1 간단 예제

# %%
train_data = [
    ("I love you", "P"),
    ("love happy weekend", "P"),
    ("bore work job", "N"),
    ("I hate you", "N"),
    ("bore weekend", "N"),
    ("happy together", "P")
]

# %%
from konlpy.tag import Mecab

# %%
def my_tokenizer(txt):
    return [t for t in Mecab.morphs(txt) if len(t) > 1]

# %%
sentiment_dict.get(0, [])
# Out:
# []

# %%
unique_tokens = []
sentiment_dict = {}
for sent, label in train_data:
    tokens = sent.split()
    unique_tokens.extend(tokens)
    sentiment_dict[label] = sentiment_dict.get(label, []) + tokens


word2idx = {v:i for i, v in enumerate(set(unique_tokens))}
word2idx, sentiment_dict
# Out:
# ({'work': 0,
#   'I': 1,
#   'you': 2,
#   'weekend': 3,
#   'bore': 4,
#   'together': 5,
#   'happy': 6,
#   'love': 7,
#   'job': 8,
#   'hate': 9},
#  {'P': ['I', 'love', 'you', 'love', 'happy', 'weekend', 'happy', 'together'],
#   'N': ['bore', 'work', 'job', 'I', 'hate', 'you', 'bore', 'weekend']})

# %%
# 토큰별 긍정/부정에서의 조건부 확률 계산

sentiment_logs = []
k = 0.5

for token in word2idx:
    temp = []
    for label in sentiment_dict:
        # 특정 라벨에서 토큰 몇 번 등장하는지 카운팅
        prob = (sentiment_dict[label].count(token) + k) / (len(sentiment_dict[label]) + 2*k)
        temp.append(np.log(prob))
    sentiment_logs.append(temp)
    
sentiment_logs
# Out:
# [[-2.890371757896165, -1.791759469228055],
#  [-1.791759469228055, -1.791759469228055],
#  [-1.791759469228055, -1.791759469228055],
#  [-1.791759469228055, -1.791759469228055],
#  [-2.890371757896165, -1.2809338454620642],
#  [-1.791759469228055, -2.890371757896165],
#  [-1.2809338454620642, -2.890371757896165],
#  [-1.2809338454620642, -2.890371757896165],
#  [-2.890371757896165, -1.791759469228055],
#  [-2.890371757896165, -1.791759469228055]]

# %%
sentiment_logs[word2idx['happy']]   # 0번째: 긍정, 1번째: 부정
# Out:
# [-1.2809338454620642, -2.890371757896165]

# %%
total_tokens = len(sum([v for v in sentiment_dict.values()], []))
total_tokens
# Out:
# 16

# %%
prob_logs = []
for label in sentiment_dict:
    prob_logs.append(np.log(len(sentiment_dict[label]) / total_tokens))

prob_logs
# Out:
# [-0.6931471805599453, -0.6931471805599453]

# %%
# predict
target_text = "happy weekend"
target_tokens = target_text.split()

log_sum = [prob_logs[0], prob_logs[1]]  # prob_logs.copy()

for token in target_tokens:
    log_sum[0] += sentiment_logs[word2idx[token]][0]
    log_sum[1] += sentiment_logs[word2idx[token]][1]

log_sum
# Out:
# [-3.7658404952500644, -5.375278407684165]

# %%
(np.exp(log_sum[0]) / (np.exp(log_sum[0]) + np.exp(log_sum[1])), np.exp(log_sum[1]) / (np.exp(log_sum[0]) + np.exp(log_sum[1])))
# Out:
# (0.8333333333333334, 0.1666666666666666)

# %%
# NBC
# 영문 / 한글 텍스트 전처리 (토큰화, 불용어 처리, 원형 복원 등)

class NBC:
    """
    나이브 베이즈 분류기 모델 클래스
    word2idx
    sentiment_logs
    prob_logs
    """
    def __init__(self, k=0.5, tokenizer=None):
        self.tokenizer = tokenizer
        self.k = k

    def fit(self, train_data:list[tuple]) -> None:
        # NLP 학습을 위한 사전 처리
            # 1. 전체 문서 토큰화
            # 2. 토큰 사전 구축
        unique_tokens = []
        sentiment_dict = {}
        for sent, label in train_data:
            tokens = self.tokenizer(sent) if self.tokenizer else sent.split()
            sentiment_dict[label] = sentiment_dict.get(label, []) + tokens
            unique_tokens += tokens

        word2idx = {v: k for k, v in enumerate(set(unique_tokens))}
        self.word2idx = word2idx

        # 토큰들의 사전 확률 계산
            # 1. 긍정/부정 별 토큰 데이터 구축
            # 2. 긍정에서 토큰이 몇 번 등장하였는지, 부정에서 토큰이 몇 번 등장하였는지 카운팅
            # 3. 긍정/부정 별 조건부 확률 계산 (laplace smoothing)
            # 4. 언더플로우 방지를 위한 log 씌우기

        sentiment_logs = []
        for token in word2idx:
            temp = []
            for label in sentiment_dict:
                # 특정 라벨에서 토큰 몇 번 등장하는지 카운팅
                prob = (sentiment_dict[label].count(token) + self.k) / (len(sentiment_dict[label]) + 2 * self.k)
                temp.append(np.log(prob))
            sentiment_logs.append(temp)
        self.sentiment_logs = sentiment_logs
        
        # 긍정/부정 사전 확률 계산
            # 긍정 토큰 수 / 전체 토큰 수
            # 부정 토큰 수 / 전체 토큰 수
            # log 씌우기
        prob_logs = []
        for label in sentiment_dict:
            prob_logs.append(np.log(len(sentiment_dict[label]) / len(unique_tokens)))
        self.prob_logs = prob_logs
            
    def predict(self, test_data:list[str]) -> list[int]:
        # 텍스트가 주어졌을 때, 긍정/부정으로 분류
        # 생각해볼 사항: 학습 때 보지 못한 토큰 처리를 어떻게 할 것인가??
        result = []
        for target_text in test_data:
            target_tokens = self.tokenizer(target_text) if self.tokenizer else target_text.split()

            log_sum = self.prob_logs.copy()
            for token in target_tokens:
                # 학습하지 못한 토큰 처리
                if token in self.word2idx:
                    for label_idx in range(len(log_sum)):
                        log_sum[label_idx] += self.sentiment_logs[self.word2idx[token]][label_idx]
            
            predict_prob = []
            for l in log_sum:
                predict_prob.append(np.exp(l) / sum(np.exp([v for v in log_sum])))
            print(predict_prob)
            result.append(np.argmax(predict_prob))

        return result

# %%
nbc = NBC()
nbc.fit(train_data)

# %%
nbc.predict([sent for sent, v in train_data])
# Out:
# [0.8333333333333331, 0.16666666666666677]
# [0.9615384615384616, 0.03846153846153839]
# [0.02173913043478259, 0.9782608695652173]
# [0.25000000000000017, 0.7499999999999999]
# [0.1666666666666666, 0.8333333333333334]
# [0.9375, 0.062499999999999944]
# [0, 0, 1, 1, 1, 0]

# %%
X_train = [t[0] for t in text]
Y_train = [t[1] for t in text]
X_train
# Out:
# ['I love you',
#  'love happy weekend',
#  'bore work job',
#  'I hate you',
#  'bore weekend',
#  'happy together']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
clf = MultinomialNB().fit(X_train_counts, Y_train)

# %%
print(clf.predict(count_vect.transform(["happy weekend"])))
print(clf.predict_proba(count_vect.transform(["happy weekend"])))
# Out:
# ['P']
# [[0.25 0.75]]

# %% [markdown]
# ## 2.2 네이버 영화 리뷰 감정분석

# %%
# 네이버 영화 리뷰 다운로드
# !wget https://github.com/e9t/nsmc/raw/master/ratings.txt

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./ratings.txt",sep='\t').dropna()
df
# Out:
#               id                                           document  label
# 0        8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1        8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2        4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3        9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4       10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1
# ...          ...                                                ...    ...
# 199995   8963373                                     포켓 몬스터 짜가 ㅡㅡ;;      0
# 199996   3302770                                              쓰.레.기      0
# 199997   5458175                  완전 사이코영화. 마지막은 더욱더 이 영화의질을 떨어트린다.      0
# 199998   6908648                왜난 재미없었지 ㅠㅠ 라따뚜이 보고나서 스머프 봐서 그런가 ㅋㅋ      0
# 199999   8548411                                    포풍저그가나가신다영차영차영차      0
#
# [199992 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

def mytokenizer(x) :
    return x.split()

X_train, X_test, y_train, y_test = train_test_split(df['document'], df['label'], random_state = 0)
count_vect = CountVectorizer(tokenizer=mytokenizer)
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)
# Out:
# c:\Users\leoni\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
count_vect.vocabulary_
# Out:
# {'이거': 248824,
#  '예전에': 231605,
#  '봤는데': 150632,
#  '감독에게': 24992,
#  '하고싶은말은': 337339,
#  '단하나다.': 82116,
#  '사람가지고': 161253,
#  '놀리지마라.': 74288,
#  '갈피를': 24607,
#  '못잡고': 123308,
#  '헤매는': 347772,
#  '캐릭터들': 319362,
#  '마틴': 106989,
#  '프리먼': 335568,
#  '널': 71328,
#  '사랑해ㅠㅠㅠㅠㅠㅠ': 162388,
#  '아': 193265,
#  '애기보다': 207467,
#  '귀여워': 45985,
#  '쯔요시를': 306073,
#  '주기지마러줘~~료코니까': 292673,
#  '10박어~!!ㅋㅋㅋ': 4459,
#  '너무현실적이여서너어무우우우우마음아프다.': 71190,
#  '.': 2357,
#  '.먹먹해진다': 3397,
#  '난': 64311,
#  '뭐...': 127863,
#  '그다지...': 47105,
#  '딱': 98388,
#  '어린이용': 212137,
#  '위대한개츠비를잘보여주는영화': 244058,
#  '영화평점': 230314,
#  '거의처음등록하는듯': 32702,
#  '존나짜증나서쓴다돼지의왕하고': 287793,
#  '창': 308430,
#  '재밌게봤다': 274247,
#  '근데이건쓰레기임': 50807,
#  '이': 248751,
#  '애니에는': 207816,
#  '정상적인캐릭터가': 283247,
#  '단한명도없음': 82125,
#  '다': 78474,
#  '그러려니해도': 47875,
#  '스토리의개연성이': 181190,
#  '쥐뿔도없는': 297121,
#  '억지': 213831,
#  '막장스토리라': 107398,
#  '1점도': 6587,
#  '아깝다': 194150,
#  '역시': 221268,
#  '폴': 333682,
#  '버호벤!!': 140085,
#  '후;;': 352691,
#  '겨우다봣네': 34929,
#  '의리있어': 248131,
#  '보인다': 147002,
#  '왠지...이영화...': 237589,
#  '진짜': 301680,
#  '재미없었다.': 272426,
#  '남는': 65577,
#  '것도': 34192,
#  '없고...': 215536,
#  '나는': 60830,
#  '돼지였다': 91745,
#  '고로': 37376,
#  '부정할': 152917,
#  '수': 176766,
#  '없는': 215891,
#  '씁쓸한영화': 192929,
#  '나와': 62952,
#  '코드가': 320768,
#  '잘': 267097,
#  '맞지': 113640,
#  '않는': 204171,
#  '감동영화인': 25609,
#  '듯하다.': 97042,
#  '모든': 119575,
#  '사람이': 161523,
#  '감동적이다': 25955,
#  '해서': 344290,
#  '나에게도': 61968,
#  '감동적으로': 25898,
#  '느껴지는': 76661,
#  '건': 33079,
#  '아닌': 195654,
#  '듯.': 96968,
#  '상대적': 165788,
#  '혹은': 349893,
#  '개인': 31243,
#  '취향.': 317395,
#  '소피마르소의': 175395,
#  '최고': 313464,
#  '작품': 266119,
#  '이런프로그렘은': 251787,
#  '많이': 110594,
#  '생겨야한다!!': 168532,
#  '나이틀리': 63645,
#  '역': 220872,
#  '제레미': 284719,
#  '노덤...딱이다!': 72720,
#  '정말': 282416,
#  '재밌게': 274139,
#  '봤던': 151160,
#  '영화.': 225714,
#  '다시': 79919,
#  '보고싶어.ㅜㅜ': 143814,
#  '사람이찢어져죽어가는데': 161604,
#  '웃을수가있을까,': 242560,
#  '세상이갈수록더러워진다,잔인성up쓰레기영화': 173170,
#  'no': 15954,
#  '에로틱,': 218040,
#  '미스테리,': 130490,
#  '스릴...': 179447,
#  '지겹게': 297802,
#  '흐르는': 354463,
#  '시간': 182746,
#  '투사부일체랑': 326736,
#  '똑같다': 100455,
#  'oo색기들': 16431,
#  '걍': 31997,
#  '그렇습니다....': 48569,
#  '비슷한': 156761,
#  '소재': 175006,
#  '진행': 302528,
#  '재미를': 271774,
#  '추구하는': 315421,
#  '요즘': 238507,
#  '영화와': 229269,
#  '다르게': 79032,
#  '주옥같은': 293628,
#  '대사와': 85183,
#  '소소한': 174692,
#  '재미': 271412,
#  '감동을': 25622,
#  '주는': 292712,
#  '영화입니다': 229763,
#  '한참동안': 342374,
#  '이런영화를': 251624,
#  '못봐왔는데': 122992,
#  '근래에': 50831,
#  '가장': 22835,
#  '잼있게': 277037,
#  '본': 147899,
#  '영화': 225502,
#  '추천합니다': 316042,
#  '코빅하는시간=나의힐링시간': 321450,
#  '언제나': 214361,
#  '내': 67662,
#  '감성과': 26629,
#  '겹쳐지는': 36017,
#  '빔': 158050,
#  '벰': 141580,
#  '더': 86425,
#  '스': 179330,
#  '의': 247957,
#  '이감독': 248797,
#  '좋은시나리오': 291741,
#  '망치는데': 113007,
#  '일가견이': 258766,
#  '있는듯...': 262131,
#  '인사동': 257780,
#  '스캔들도': 180074,
#  '그렇고': 48454,
#  '달달한': 82220,
#  '영화다': 227521,
#  'ㅠㅠ': 20647,
#  '눙무리...': 76392,
#  '엔딩이': 218765,
#  '너무': 69916,
#  '인상깊다': 257809,
#  'ㅋㅋ': 19242,
#  '아니': 194765,
#  '이게': 249718,
#  '뭔': 128719,
#  '공포냐,,,': 40086,
#  '런닝타임도': 102430,
#  '짧고': 304704,
#  '나름': 61229,
#  '평도': 331176,
#  '좋아서': 290315,
#  '특히': 327622,
#  '마지막부분이': 106567,
#  '무섭다고해서': 125511,
#  '긴장하고': 54616,
#  '봤다가': 151022,
#  '쓴웃음만': 192755,
#  '나왔다,,,': 63183,
#  '언제쩍': 214437,
#  '주온': 293631,
#  '컨셉이냐,,,,': 320110,
#  '러브크래프트': 102293,
#  '분위기의': 153937,
#  '종말론적': 289282,
#  '이야기.존카펜터': 254140,
#  '더씽과': 87021,
#  '더불어': 86820,
#  '최고의': 314052,
#  '가이리치는': 22794,
#  '어디간거야?': 210981,
#  '재난영화로': 271276,
#  '만들어': 108648,
#  '버리다.': 139813,
#  '재난영화': 271256,
#  '에이리언vs프레데터2가': 218295,
#  '나올걸?': 62766,
#  '그': 46388,
#  '시점에서': 184837,
#  '흥미있는': 355552,
#  '시도.': 183849,
#  '브로디': 155596,
#  '귀엽고': 46115,
#  '매력적이져.': 114360,
#  '보고': 143584,
#  '있으면': 263171,
#  '눈이': 76270,
#  '즐거운': 297296,
#  '사실입니다.': 162942,
#  '그런데': 48131,
#  '지금': 297949,
#  '가수오디션인지': 22320,
#  '미인대회인지': 130791,
#  '모르겠네요.': 119828,
#  '방송': 137345,
#  '장난으로': 269981,
#  '합니까?': 343444,
#  '떨어진': 99964,
#  '얘들중에': 210660,
#  '노래': 72783,
#  '잘하는': 268630,
#  '얘들이': 210658,
#  '얼마나': 214783,
#  '많은데': 110484,
#  '노래할': 72962,
#  '줄도': 295569,
#  '모르는': 120091,
#  '브로디를': 155602,
#  '살려줍니까.': 164296,
#  '악마에게': 199830,
#  '영혼을': 225492,
#  '팔고도': 329209,
#  '잘도': 267219,
#  '구원받았다.': 44006,
#  '암울하고': 206865,
#  '찝찝한': 306844,
#  '분위기': 153871,
#  '쓰읍...': 192613,
#  'cg와': 14226,
#  '그래픽빼면': 47599,
#  '재미없눈영화': 272014,
#  '하녀들?': 337978,
#  "that's": 17463,
#  'nono.': 15969,
#  '우리': 239732,
#  '딸': 98672,
#  '보다': 145069,
#  '내가': 67677,
#  '신나게': 186113,
#  '왔네요ㅎㅎㅎ': 236326,
#  '정말소방관분들존경합니다': 282669,
#  '마이키': 106387,
#  '이야기엄청재미있어용': 254262,
#  '이번건': 252598,
#  '안보는게': 202047,
#  '좋음': 292028,
#  '노잼임': 73474,
#  '달달하니': 82214,
#  '첫': 311214,
#  '사랑': 161688,
#  '생각나서': 167523,
#  '좋다': 289976,
#  'ㅋㅋㅋ': 19285,
#  '끝나고': 59601,
#  '한참을': 342385,
#  '울었네요...': 241412,
#  '이딴': 250753,
#  '영화가': 226777,
#  '평점이8점을': 332139,
#  '넘을려고': 71843,
#  '하다니': 338418,
#  'ㅉㅉ': 19145,
#  '깊이': 56178,
#  '생각하는': 168058,
#  '척': 310290,
#  '하는': 338005,
#  '영화자체가': 229863,
#  '챌린저급': 309445,
#  '설계': 170845,
#  '실험적이고': 188132,
#  '흥미로운': 355425,
#  '진짜재밌었다': 302316,
#  '이런영화또보고싶다': 251618,
#  '손발': 175988,
#  '오그라든다.': 232066,
#  '최악의': 314790,
#  '로맨틱': 103373,
#  '코메디중': 320918,
#  '하나.': 337531,
#  '출근길에': 316306,
#  '드라마인데..ㅋ': 95358,
#  '재미있었습니다.': 273406,
#  '답답해서': 83213,
#  '슬픈...': 182252,
#  '도전은': 88823,
#  '좋은데..........이건좀......재미도': 291619,
#  '없고': 215508,
#  '개봉하는': 30597,
#  '날': 64849,
#  '비극을': 156153,
#  '희극으로': 355938,
#  '표현할': 334303,
#  '줄': 295455,
#  '아는': 194696,
#  '신(모차르트)의': 185846,
#  '한수가': 341870,
#  '느껴지더군요...': 76687,
#  '세트도': 173398,
#  '화려하고.': 350833,
#  '요새': 238338,
#  '볼': 148618,
#  '영화도': 227739,
#  '없는데': 216045,
#  '후궁탈출': 352718,
#  '완전': 235787,
#  '강춥니다!!!': 28377,
#  '꿀잼!!강력추천!!!': 58578,
#  '원작': 243188,
#  '자체만으로10점이상이고': 265509,
#  '점수': 281604,
#  '매기는게': 113933,
#  '무의미한': 126286,
#  '작품이긴한데': 266390,
#  '작품은': 266366,
#  '과거': 40570,
#  '티비': 327982,
#  '방영시절의': 137599,
#  '성우들이': 172139,
#  '작품과': 266210,
#  '맞는거': 113382,
#  '같습니다.': 28994,
#  '리마스터링': 104432,
#  '극장판은': 50523,
#  '과거의': 40617,
#  '성우가': 172105,
#  '아니네요.ㅠ.,ㅠ': 194992,
#  '재잘거리는': 276247,
#  '앤의': 209197,
#  '맛과': 112461,
#  '시니컬한': 183689,
#  '마릴라의': 105566,
#  '맛을': 112531,
#  '못살림': 123142,
#  '봤습니다....,': 151290,
#  '취향이': 317424,
#  '아니구나...': 194917,
#  '언론의': 214266,
#  '맹점과': 115132,
#  '군중심리.': 44858,
#  '개인의심리까지': 31272,
#  '파헤치면서도': 328895,
#  '재미까지': 271536,
#  '균형을': 46379,
#  '맞춘': 113722,
#  '멋진영화': 116978,
#  '소재도': 175056,
#  '좋고': 289767,
#  '스릴도': 179499,
#  '있고': 261630,
#  '적당히': 278739,
#  '긴장감도': 54499,
#  '돌고...': 90042,
#  '이정도면': 255496,
#  '만든': 108106,
#  '영화입니다.': 229774,
#  '저는': 277638,
#  '아주': 198903,
#  '잘봤습니다.': 267982,
#  '링컨과': 105117,
#  '케네디의': 320355,
#  '일치점은': 260304,
#  '평행이론이라는': 332547,
#  '책은': 309343,
#  '영화에서만': 228886,
#  '존재하는': 288018,
#  '것이었네요.': 34396,
#  '읽어볼려고': 260544,
#  '찾아봤네요': 308840,
#  '제작비': 285473,
#  '차라리': 307064,
#  '기부를했으면': 53024,
#  '좀더': 288828,
#  '따뜻한': 97805,
#  '세상이': 173169,
#  '오지': 233779,
#  '않았을까요?': 204699,
#  '프랑스': 335149,
#  '티비에서': 328047,
#  '지금했는데': 298192,
#  '얼마전개봉작?!!': 214836,
#  '암튼': 206922,
#  '하도': 338549,
#  '쓰레기같아서': 192005,
#  '혹시하고': 349888,
#  '네이버에': 72390,
#  '찾았음': 308962,
#  'ㅋ아': 20135,
#  '진심...연기를': 301327,
#  '안해!!배우들이!!!게다가': 203796,
#  '상어': 166111,
#  '에': 217717,
#  '폭발신..심지어': 333472,
#  '배우들': 138534,
#  '가슴까지!!다': 22355,
#  '가짜티남': 23537,
#  'ㅋㅋ1점도': 19265,
#  '아깝다진짜': 194326,
#  '매력적인': 114366,
#  '재미있게': 272757,
#  '봤지만': 151787,
#  '몬가': 121422,
#  '아쉬웠던': 197711,
#  ';;': 12855,
#  '잘만든영화': 267406,
#  '참': 307812,
#  '재밌게봤습니다.': 274277,
#  '2012년에': 7441,
#  '90년대': 12422,
#  '연출.': 223487,
#  '잘봤네요.': 267951,
#  '향수에': 346406,
#  '젖었어요.': 284402,
#  '시바.': 184139,
#  '웜홀을': 243814,
#  '타고': 323693,
#  '넘어와서': 71777,
#  '만들었나....연출공부좀': 109066,
#  '하쇼.': 338918,
#  '미국에': 129571,
#  '반하는': 135567,
#  '내용이면': 69138,
#  '좌좀이냐?': 292196,
#  '답없는새끼들..': 83297,
#  '이건': 249238,
#  '똥쓰레기': 100759,
#  '영화는': 227448,
#  '드래곤볼': 95540,
#  '아니다': 195008,
#  'ㅡㅡ': 20946,
#  'gt도': 15118,
#  '이것보단': 249680,
#  '9999억배': 12633,
#  '재미있다': 273028,
#  '이런': 251110,
#  '괴작+졸작+망작영화는': 42841,
#  '절~~~때로': 281059,
#  '안보는걸': 202040,
#  '추천함': 316033,
#  '존': 287582,
#  '카펜터다운': 319028,
#  'b급': 13876,
#  '참신한': 308171,
#  '소재에': 175112,
#  '막장': 107271,
#  '스토리': 180685,
#  '장르에': 270306,
#  '코미디는': 320988,
#  '왜': 236649,
#  '들어가있는': 96399,
#  '지': 297720,
#  '모르겠네...': 119817,
#  '개막장영화..': 30184,
#  '조윤희때문에3점준다': 286872,
#  '특수효과가': 327478,
#  '오히려': 234095,
#  '영화를': 228124,
#  '망쳐버린듯': 112951,
#  '...': 2384,
#  '시즌3의': 184980,
#  '복선이라고': 147620,
#  '믿어': 131966,
#  '의심치': 248516,
#  '않는다....능....': 204233,
#  '하앍!!!': 339088,
#  '잘봤다고': 267966,
#  '말한다': 112129,
#  '인간이라면': 257202,
#  '출구를': 316303,
#  '찾을': 308989,
#  '마음이': 106190,
#  '있다': 262244,
#  '깨알': 57068,
#  '캐스팅과': 319532,
#  '질퍽하지않은': 303037,
#  '산뜻한': 163887,
#  '내용구성이': 68863,
#  '버무러진': 139898,
#  '깨알일드!!♥': 57083,
#  'ebs': 14710,
#  '명화에서': 118965,
#  '이거보고': 248990,
#  '움': 241678,
#  '진짜감동적': 301852,
#  '계속': 36653,
#  '오글오글거려서': 232239,
#  '결국': 35344,
#  '못보고': 122887,
#  '말았습니다.': 111446,
#  'ㅎㅎㅎ대사도': 20305,
#  '내용도': 68876,
#  '넘': 71387,
#  '유치해요.중학생': 246096,
#  '미만용': 130083,
#  '시작부터': 184585,
#  '도전이라는': 88829,
#  '느낌보다': 77256,
#  '무모함에': 124972,
#  '가까워보이는': 21348,
#  '느낌이었지만': 77384,
#  '끝은': 60150,
#  '부러움이었습니다.': 152134,
#  '그들이': 47350,
#  '해내서': 343855,
#  '기뻤고': 53261,
#  '감동이었어요.청춘과': 25754,
#  '청년이': 311423,
#  '조합된': 287456,
#  '무모함과': 124970,
#  '패기에': 329459,
#  '반했습니다.': 135635,
#  'i': 15274,
#  'mavri': 15702,
#  'emmanouella': 14755,
#  '앞에': 207292,
#  'i가': 15365,
#  '빠졌슴...ㅡㅡ^': 158626,
#  '그냥': 46689,
#  '머리': 115310,
#  '쓰지': 192643,
#  '않고': 203988,
#  '가볍게': 22127,
#  '보면': 145591,
#  '되는': 92136,
#  '완성도는': 235705,
#  '떨어진다': 99967,
#  '야...': 209310,
#  '몰입도': 121887,
#  '안되고..': 201043,
#  '없다': 216132,
#  '중국의': 296272,
#  '거대': 32230,
#  '자본은': 264635,
#  '미치게': 131017,
#  '하다.': 338388,
#  '봤지만,,': 151791,
#  '아직도': 199113,
#  '내돈': 68120,
#  '!!!!': 3,
#  '한국공포는': 340440,
#  '여전함': 220519,
#  '당시': 83452,
#  '암울한': 206873,
#  '한국을': 340878,
#  '그렸다.': 48769,
#  '지금도..': 298026,
#  '일려나?': 259011,
#  '한국': 340418,
#  '시실리2km': 184352,
#  '삘난다': 160464,
#  'ㅋㅋㅋㅋ': 19319,
#  '별기대안했었는데': 142161,
#  '오페라의유령보다': 233967,
#  '훨감동적이었다': 353951,
#  '2.22': 7151,
#  '만들어보자': 108789,
#  '제군들이여': 284559,
#  '3류독립영화보다못한영화': 9198,
#  '그냥보는': 46847,
#  '내내답답한': 68001,
#  '시간낭비': 182827,
#  '스릴러냐이게': 179566,
#  '드라마지': 95451,
#  '10년만에': 4336,
#  '흉내도못내는지루함': 354403,
#  '졸려': 288282,
#  '빨리보기로': 159025,
#  '5분보면': 10701,
#  '내용다알어': 68872,
#  '돈아까워!!!': 89636,
#  '재미지당': 273649,
#  'ㅎㅎ': 20244,
#  '개이득이양!': 31232,
#  '아...': 193293,
#  '다시보고': 79989,
#  '싶은데': 190046,
#  '어디서': 211049,
#  '다시보지?usb에': 80113,
#  '넣고': 72101,
#  '싶은': 189993,
#  '1인.': 6479,
#  '하지만': 339458,
#  '상상을': 165934,
#  '초월할': 312665,
#  '만큼': 109858,
#  '위대하다고': 244048,
#  '영화라고': 227833,
#  '평가한다.': 331084,
#  '일당백': 258925,
#  'ㅎㅎㅎ': 20275,
#  '사랑하지': 162279,
#  '않을': 204872,
#  '매력쟁이': 114285,
#  '히어로들.': 356346,
#  '박력넘치고': 133769,
#  '탄탄했던': 324375,
#  '플롯이': 335738,
#  '시즌': 184869,
#  '2부터': 8268,
#  '무너진점은': 124601,
#  '너무나': 70046,
#  '슬픈일이지만,': 182350,
#  '이만큼': 252277,
#  '매력': 114113,
#  '살린건': 164399,
#  '대단한': 84191,
#  '연출의': 223680,
#  '힘일': 357057,
#  '터..작가진': 325170,
#  '문제만': 127002,
#  '없었어도': 216959,
#  '다시없을': 80228,
#  '명작이': 118535,
#  '됐을텐데..': 91883,
#  '그래도': 47488,
#  '캐릭터가': 319341,
#  '살림': 164432,
#  '완벽하게': 235585,
#  '재밌다.': 274788,
#  '새끼들이': 166818,
#  '나의': 63491,
#  '쿵푸팬더를': 322085,
#  '모욕했어.': 120741,
#  '평점테러나': 332426,
#  '먹어라': 115891,
#  '기대는': 51992,
#  '안했는데...보고나선': 203855,
#  '잘봤다는': 267968,
#  '생각이...최강코믹': 167854,
#  '목욕탕에': 121306,
#  '금붕어풀고': 51294,
#  '비비탄총들고': 156639,
#  '스마트폰으로찍어도': 179824,
#  '이거보단': 249029,
#  '재밋갰내': 273709,
#  '내용이며': 69135,
#  '연기': 221787,
#  '다ooo이고': 78490,
#  '핼기날아댕기고': 345267,
#  '총쏘고': 313118,
#  '미사일': 130177,
#  '날리고': 65015,
#  '그래픽이씨1발': 47624,
#  '가관이다': 21298,
#  '불후의': 155197,
#  '명작이란': 118626,
#  '칭호는': 318611,
#  '괜히': 42564,
#  '달리는게': 82444,
#  '아니다...': 195022,
#  '티비에': 328046,
#  '제발': 284980,
#  '한번쯤': 341750,
#  '나와라3사': 62982,
#  '방송국에': 137365,
#  '나와야': 63025,
#  '..아이들이': 3120,
#  '볼텐데': 149581,
#  '말이죠..아니면': 111692,
#  '영심이나': 225076,
#  '하니': 338365,
#  '이런거': 251165,
#  '안나옴?맨날': 200573,
#  '애들': 207942,
#  '만화보면': 109994,
#  '로봇트나': 103610,
#  '나와서': 62999,
#  '때려': 98936,
#  '부시기만하지..': 152652,
#  '일본인이': 259601,
#  '천성이': 310532,
#  '더럽고': 86669,
#  '쓰래기라는걸': 191809,
#  '보여준': 146587,
#  '평점이': 332122,
#  '높다': 74625,
#  '이정돈아님': 255535,
#  '8점은': 12235,
#  '되요~': 92789,
#  '평점': 331514,
#  '올려주기~': 234538,
#  '애아빠가': 208331,
#  '곡괭이로': 38662,
#  '배가': 137834,
#  '뚫렸는데도,총들고': 100953,
#  '옆에서': 230542,
#  '보고만': 143673,
#  '있는': 261953,
#  '마누라라니...': 105255,
#  '알바': 205755,
#  '돋네;': 89891,
#  '레알': 102621,
#  '1편도': 6965,
#  '그랬지만': 47771,
#  '2편도': 8580,
#  '참;': 307914,
#  '춤도': 316784,
#  '별로요': 142563,
#  '음악도': 247602,
#  '별로니': 142357,
#  '뭘': 129028,
#  '보라는건지': 145381,
#  '맨': 114886,
#  '마지막': 106473,
#  '장면': 270372,
#  '빼곤': 159292,
#  '지루함;;;': 299223,
#  '강민혁이랑이종현땜에봣는데정말재밋다♥♥♥': 27848,
#  '갑자기': 27363,
#  '실검': 187214,
#  '뜨는': 101277,
#  '이유가': 255132,
#  '뭔가요??': 128800,
#  '다운받았다': 80516,
#  '있는데': 262080,
#  '개신기;;': 30987,
#  '나오는': 62203,
#  '만들지?': 109343,
#  "'그들은": 794,
#  '폭풍우로': 333626,
#  "뛰어들었을까'": 101169,
#  '지나친': 298364,
#  '비의': 157013,
#  '억지눈물..억지연기..': 213911,
#  '꼭': 57807,
#  '평점을': 332095,
#  '남겨주세요.': 65294,
#  '사랑은': 162011,
#  '현실을': 348448,
#  '잊게': 263607,
#  '한다....': 341151,
#  '4점': 10189,
#  '정도가': 282187,
#  '적당함': 278722,
#  '연출은': 223672,
#  '나았지만': 61941,
#  '스토리가': 180830,
#  '영....': 224581,
#  '떼우기': 100125,
#  '용': 239118,
#  '수십번봤다..': 177307,
#  '요즘초딩은': 238616,
#  '인터넷하고': 258622,
#  '그러니': 47849,
#  '수십번봐야하나': 177306,
#  '모르지;;': 120192,
#  '좋게': 289529,
#  '볼려고': 148926,
#  '했는데도': 345490,
#  '이런소재는': 251483,
#  '지루하면': 298978,
#  '안되는데': 201183,
#  '지루한건': 299059,
#  '어쩔': 213461,
#  '없네': 215774,
#  '가족의': 23297,
#  '소중함을': 175238,
#  '일깨워준': 258868,
#  '영화..': 225721,
#  '단순한': 81842,
#  '추억의': 315705,
#  '이상.,': 253215,
#  '말이': 111545,
#  '필요': 336639,
#  '없음.': 217176,
#  '후크는': 353214,
#  '초딩2학년(현재': 312299,
#  '29살)': 7975,
#  '때': 98889,
#  '영화로': 228056,
#  '인생': 257982,
#  '걸작이었다!': 33787,
#  '어른이': 211874,
#  '되어': 92513,
#  '빡빡한': 158797,
#  '회사원으로': 352385,
#  '사는': 161004,
#  '피터팬을': 336245,
#  '찾아온': 308886,
#  '팅커벨': 328225,
#  '그리고': 48852,
#  '그림자의': 49172,
#  '향수는': 346399,
#  '생생하다.': 168847,
#  '헌데': 347375,
#  '꿈을': 58802,
#  '잃은': 260731,
#  '피터팬처럼': 336249,
#  '매일': 114547,
#  '하루하루를': 338745,
#  '살고': 164136,
#  '있다.': 262258,
#  '오늘': 232326,
#  '악몽을': 199857,
#  '꿀꺼같다..': 58538,
#  '너무잔인한': 70603,
#  '군부정권ㅡㅡ..': 44775,
#  '이렇게': 251842,
#  '자유롭게': 265234,
#  '표현할수있는것도': 334314,
#  '저런분들덕분이다': 277848,
#  '명작중': 118750,
#  '대명작...': 84526,
#  '김태희': 55907,
#  '때문에': 99074,
#  '간신히': 24107,
#  '끝까지': 59491,
#  '봤다': 150900,
#  '자체는': 265486,
#  '쓰레기': 191882,
#  '주윤발이': 293752,
#  '돈때문에': 89501,
#  '찍은것': 306635,
#  '같은': 29250,
#  '경쾌한': 36475,
#  '리듬의': 104416,
#  '사랑학': 162284,
#  '강의': 28100,
#  '돈을': 89730,
#  '가지게': 23384,
#  '되면은': 92387,
#  '섹스와': 173503,
#  '마약에': 105976,
#  '중독되서': 296380,
#  '최후에는': 315262,
#  '비참하게': 157178,
#  '인간이': 257181,
#  '성적으로': 172511,
#  '어디까지': 210998,
#  '타락할수': 323773,
#  '있는지': 262197,
#  '영화에서': 228875,
#  '보여주는거': 146453,
#  '같다.': 28835,
#  '심하게': 189153,
#  '선정적인': 170621,
#  '장면이': 270517,
#  '나온다.하지만': 62646,
#  '3시간이라는': 9454,
#  '러닝타임이': 102203,
#  '지루하지는': 298993,
#  '않다.': 204320,
#  '으아...손발이없어진다....': 246912,
#  '오글오글...': 232235,
#  '패기나열정만으로는': 329450,
#  '아무것도': 197110,
#  '해결되지': 343755,
#  '않는다.창작자로써': 204255,
#  '감독의내공이': 25032,
#  '딸림.': 98756,
#  '다시보고싶은데': 80021,
#  '자료': 264429,
#  '못구하나요?': 122373,
#  '2배속으로': 8187,
#  '봤음,,그래도': 151707,
#  '지루했다': 299423,
#  '~~~~~~~~~': 18242,
#  '워쇼스키': 242809,
#  '형제의': 349157,
#  '힘': 356585,
#  '왜구': 236757,
#  '답다': 83061,
#  'ㅋㅋㅋㅋㅋㅋㅋ': 19337,
#  '내내': 67993,
#  '울었다..멍해진다': 241450,
#  '여운도': 219861,
#  '남고': 65327,
#  '개인적으로': 31278,
#  '라비앙': 101726,
#  '로즈라는': 103706,
#  '노래는': 72823,
#  '인연이': 258301,
#  '깊은': 56144,
#  '노래라': 72855,
#  '노래를': 72860,
#  '부른': 152284,
#  '대체': 85751,
#  '누굴까': 75391,
#  '생각해봤습니다.': 168382,
#  '이디스': 250673,
#  '피아프를': 336091,
#  '알게되었고': 205113,
#  '감상하길': 26539,
#  '잘했다고': 268952,
#  '생각합니다.': 168276,
#  '결말은': 35547,
#  '그냥....진시황도': 46711,
#  '다이너마이트엔': 80701,
#  '못당하니': 122477,
#  '노벨이짱이란거네ㅡㅡ': 73196,
#  '전체적으로': 280590,
#  '허접하지만': 347171,
#  '잘들어보면': 267309,
#  '대사들!': 85119,
#  '쓰잘데기없는': 192635,
#  '허상일뿐': 346793,
#  '개는': 30019,
#  '개다': 30021,
#  '몰입만': 121987,
#  '하면': 338786,
#  '시간때우기는': 182960,
#  '될거': 93065,
#  '같은데..': 29316,
#  '자꾸': 264207,
#  '잠이': 269237,
#  '온다.': 234202,
#  '2번시도하다': 8223,
#  '포기함.': 332779,
#  '요리영화...': 238286,
#  '나중에': 63706,
#  '알게되겠지..': 205095,
#  '자신이': 264965,
#  '영화에': 228849,
#  '과하게': 40919,
#  '치장을': 317898,
#  '했었는지..': 345755,
#  '남의': 66101,
#  '시선을': 184264,
#  '신경쓰는건': 185894,
#  '누구보다': 75293,
#  '감독인것': 25151,
#  '과한': 40981,
#  '치장은': 317897,
#  '쓰레기만': 192197,
#  '만들뿐..': 108608,
#  '연기최악': 222699,
#  '연출최악': 223765,
#  '한니발은': 341133,
#  '어디에?': 211087,
#  '인터넷에서': 258610,
#  '총씬': 313133,
#  '과대평가된듯..': 40669,
#  '영화나': 227240,
#  '쓰는거냐?ㅋㅋ': 191678,
#  '사나이': 160940,
#  '안': 200095,
#  '되고': 91990,
#  '말지...': 111877,
#  '비틀기대명사': 157384,
#  '치곤': 317565,
#  '전형적': 280957,
#  '총들고': 313044,
#  '머뭇거렸네': 115494,
#  '북한에서': 153486,
#  '촛불': 312951,
#  '들었으면': 96720,
#  '바로': 133267,
#  '탱크에': 325156,
#  '깔려서': 56651,
#  '죽었다.': 294643,
#  '멍청한': 117153,
#  '인간들...': 257029,
#  '인생에서': 258066,
#  '와닿는': 235225,
#  '보게된것잎정말': 143468,
#  '기쁘다': 53275,
#  '무섭다': 125477,
#  '...자연재해가젤무섭': 2853,
#  '갖고': 28553,
#  '싶었던': 189923,
#  '키트.': 323370,
#  '공유bb': 39784,
#  '잘만들었네요': 267498,
#  '졸작': 288554,
#  '포스터만': 332988,
#  '봐도': 149860,
#  '노잼': 73358,
#  '예상': 231076,
#  '강우석감독은': 28064,
#  '상황이': 166718,
#  '아니라': 195150,
#  '주인공의': 293941,
#  '주둥이로': 292891,
#  '주려고한다': 292925,
#  '영화마다': 228214,
#  '진지하게': 301604,
#  '일장연설하는': 260160,
#  '부분은': 152510,
#  '이제': 255583,
#  '그만~': 49301,
#  '네이버에서': 72394,
#  '0점없어요?': 3788,
#  '굿굿': 45148,
#  ...}

# %%
X_test[:10]
# Out:
# 78888                     진짜 개웃김 ㅋㅋㅋ 이런 코드너무 좋다 언능 2나왔음 좋겠다
# 49058     고속버스타고 가는 길에 핸드폰으로 보다가 울었네요 ㅠㅠ 아 슬픈듯.. 개인적으로 진...
# 101711                           개성 없는 모방 일색의 유치하고 가벼운 오락물.
# 97260     상처가없는이들에겐 갖혀있는소녀의 저질액션 미친영화이겠으나 나에겐 꿈처럼시작해서 미련...
# 53590                               아 다시 보고 싶은데 디비디가 안나온다..
# 62095                                            김민종씨 멋집니다.
# 36349          무식하게 거대한 원양어선으로 대량포획하는 미국, 일본 등등 국가들은 반성해라!!
# 151288                                        콜럼버스는 사기꾼이었다!
# 88072                                           재미있어요 재미있어요
# 117532    일주일에 한번봐도 대충 내용이 감이 오는 뻔한 스토리젤 짜증나는건 민세현? 연기 못...
# Name: document, dtype: object

# %%
X_new_counts = count_vect.transform(X_test)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_counts)
np.mean(predicted == y_test)
# Out:
# 0.8068522740909636

# %%
# nbc 적용
nbc = NBC(tokenizer=mytokenizer)

# %%
nbc.fit(list(zip(X_train, y_train)))
